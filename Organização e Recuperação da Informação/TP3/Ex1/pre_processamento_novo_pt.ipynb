# %%
import nltk

# %%
import re

# %%
from nltk.tokenize import word_tokenize

# %%
from nltk.probability import FreqDist

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ID do corpus

# %%
nltk_id = 'mac_morpho'

# %%
nltk.download(nltk_id)
# Out:
# [nltk_data] Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]   Package mac_morpho is already up-to-date!
# True

# %%
print(nltk.corpus.mac_morpho.fileids())
#com o fileids eu consigo ver o nome dos arquivos
# Out:
# ['ag94ab12.txt', 'ag94ag02.txt', 'ag94de06.txt', 'ag94fe1.txt', 'ag94ja11.txt', 'ag94jl12.txt', 'ag94ju07.txt', 'ag94ma03.txt', 'ag94mr1.txt', 'ag94no01.txt', 'ag94ou04.txt', 'ag94se06.txt', 'br94ab02.txt', 'br94ag01.txt', 'br94de01.txt', 'br94fe1.txt', 'br94ja04.txt', 'br94jl01.txt', 'br94ju01.txt', 'br94ma01.txt', 'br94mr1.txt', 'br94no01.txt', 'br94ou01.txt', 'br94se01.txt', 'co94ab02.txt', 'co94ag01.txt', 'co94de01.txt', 'co94fe1.txt', 'co94ja04.txt', 'co94jl01.txt', 'co94ju01.txt', 'co94ma01.txt', 'co94mr1.txt', 'co94no01.txt', 'co94ou01.txt', 'co94se01.txt', 'di94ab02.txt', 'di94ag01.txt', 'di94de01.txt', 'di94fe1.txt', 'di94ja04.txt', 'di94jl01.txt', 'di94ju01.txt', 'di94ma01.txt', 'di94mr1.txt', 'di94no01.txt', 'di94ou02.txt', 'di94se01.txt', 'es94ab02.txt', 'es94ag01.txt', 'es94de01.txt', 'es94fe1.txt', 'es94ja04.txt', 'es94jl01.txt', 'es94ju01.txt', 'es94ma01.txt', 'es94mr1.txt', 'es94no01.txt', 'es94ou01.txt', 'es94se01.txt', 'fc96ma10.txt', 'fc96ma23.txt', 'if94ab13.txt', 'if94ag03.txt', 'if94de07.txt', 'if94fe16.txt', 'if94ja05.txt', 'if94jl06.txt', 'if94ju01.txt', 'if94ma04.txt', 'if94mr16.txt', 'if94no02.txt', 'if94ou05.txt', 'if94se07.txt', 'il94ab02.txt', 'il94ag01.txt', 'il94de01.txt', 'il94fe1.txt', 'il94ja04.txt', 'il94jl01.txt', 'il94ju01.txt', 'il94ma01.txt', 'il94mr1.txt', 'il94no01.txt', 'il94ou01.txt', 'ma94ab10.txt', 'ma94ag07.txt', 'ma94de04.txt', 'ma94fe13.txt', 'ma94ja16.txt', 'ma94jl03.txt', 'ma94ju05.txt', 'ma94ma01.txt', 'ma94mr13.txt', 'ma94no06.txt', 'ma94ou02.txt', 'ma94se04.txt', 'mu94ab02.txt', 'mu94ag01.txt', 'mu94de01.txt', 'mu94fe1.txt', 'mu94ja04.txt', 'mu94jl01.txt', 'mu94ju01.txt', 'mu94ma01.txt', 'mu94mr1.txt', 'mu94no01.txt', 'mu94ou01.txt', 'mu94se01.txt']

# %%
folha_sp = nltk.corpus.mac_morpho.raw('ag94ab12.txt')

# %%
print(folha_sp)
# Out:
# Jersei_N
# atinge_V
# média_N
# de_PREP
# Cr$_CUR
# 1,4_NUM
# milhão_N
# em_PREP|+
# a_ART
# venda_N
# de_PREP|+
# a_ART
# Pinhal_NPROP
# em_PREP
# São_NPROP
# Paulo_NPROP
# ._.
# Programe_V
# sua_PROADJ
# viagem_N
# a_PREP|+
# a_ART
# Exposição_NPROP
# Nacional_NPROP
# do_NPROP
# Zebu_NPROP
# ,_,
# que_PRO-KS-REL
# começa_V
# dia_N
# 25_N|AP
# ._.
# Safra_N
# recorde_ADJ
# e_KC
# disponibilidade_N
# de_PREP
# crédito_N
# ativam_V
# vendas_N
# de_PREP
# máquinas_N
# agrícolas_ADJ
# ._.
# A_ART
# degradação_N
# de_PREP|+
# as_ART
# terras_N
# por_PREP|+
# o_ART
# mau_ADJ
# uso_N
# de_PREP|+
# os_ART
# solos_N
# avança_V
# em_PREP|+
# o_ART
# ._.
# A_ART
# desertificação_N
# tornou_V
# crítica_ADJ
# a_ART
# produtividade_N
# de_PREP
# 52_NUM
# mil_NUM
# km²_N
# em_PREP|+
# a_ART
# região_N
# ._.
# Em_PREP|+
# o_ART
# dia_N
# 15_N|AP
# ,_,
# Dia_NPROP
# da_NPROP
# Conservação_NPROP
# do_NPROP
# Solo_NPROP
# ,_,
# o_ART
# único_ADJ
# fato_N
# a_PREP
# festejar_V
# pode_VAUX
# ser_V
# a_ART
# Convenção_NPROP
# Internacional_NPROP
# sobre_NPROP
# Desertificação_NPROP
# ._.
# A_ART
# produção_N
# brasileira_ADJ
# de_PREP
# pintos_N
# de_PREP
# corte_N
# totalizou_V
# ,_,
# em_PREP
# fevereiro_N
# último_ADJ
# ,_,
# 166_NUM
# milhões_N
# ,_,
# volume_N
# 6,79_NUM
# %_N
# superior_ADJ
# a_PREP|+
# o_ART
# registrado_N
# em_PREP
# fevereiro_N
# de_PREP
# 93_N
# ,_,
# segundo_PREP
# dados_N
# de_PREP|+
# a_ART
# Associação_NPROP
# Brasileira_NPROP
# dos_NPROP
# Produtores_NPROP
# de_NPROP
# Pinto_NPROP
# de_NPROP
# Corte_NPROP
# (_(
# Apinco_NPROP
# )_)
# ._.
# A_ART
# Apinco_NPROP
# destaca_V
# em_PREP
# seu_PROADJ
# boletim_N
# mensal_ADJ
# que_KS
# o_ART
# setor_N
# avícola_ADJ
# está_V
# otimista_ADJ
# com_PREP
# o_ART
# atual_ADJ
# programa_N
# de_PREP
# estabilização_N
# econômica_ADJ
# ._.
# "_"
# A_ART
# melhoria_N
# de_PREP|+
# o_ART
# padrão_N
# aquisitivo_ADJ
# resulta_V
# em_PREP
# maior_ADJ
# demanda_N
# de_PREP
# carne_N
# de_PREP
# frango_N
# "_"
# ._.
# O_ART
# secretário_N
# de_PREP|+
# a_ART
# agricultura_N
# paulista_ADJ
# ,_,
# Roberto_NPROP
# Rodrigues_NPROP
# ,_,
# aprovou_V
# o_ART
# pacote_N
# de_PREP|+
# o_ART
# trigo_N
# ,_,
# anunciado_PCP
# em_PREP|+
# o_ART
# final_N
# de_PREP
# março_N
# por_PREP|+
# o_ART
# governo_N
# federal_ADJ
# ._.
# A_ART
# nova_ADJ
# alíquota_N
# para_PREP
# importação_N
# de_PREP|+
# o_ART
# produto_N
# (_(
# 17_NUM
# %_N
# )_)
# garante_V
# a_ART
# competitividade_N
# de_PREP|+
# a_ART
# triticultura_N
# nacional_ADJ
# ,_,
# disse_V
# o_ART
# secretário_N
# ._.
# agricultores_N
# de_PREP
# o_ART
# Vale_NPROP
# do_NPROP
# Paranapanema_NPROP
# ,_,
# em_PREP
# São_NPROP
# Paulo_NPROP
# ,_,
# iniciaram_V
# ontem_ADV
# o_ART
# plantio_N
# de_PREP
# trigo_N
# duro_ADJ
# ._.
# A_ART
# variedade_N
# ,_,
# para_PREP
# a_ART
# fabricação_N
# de_PREP
# massas_N
# ,_,
# foi_VAUX
# selecionada_PCP
# por_PREP|+
# o_ART
# Instituto_NPROP
# Agronômico_NPROP
# de_NPROP
# Campinas_NPROP
# ._.
# O_ART
# governador_N
# Mário_NPROP
# Pereira_NPROP
# ,_,
# de_PREP|+
# o_ART
# Paraná_NPROP
# ,_,
# e_KC
# o_ART
# secretário_N
# de_PREP|+
# a_ART
# agricultura_N
# José_NPROP
# Carlos_NPROP
# Tibúrcio_NPROP
# aproveitaram_V
# o_ART
# palanque_N
# de_PREP|+
# a_ART
# Exposição_NPROP
# Agropecuária_NPROP
# de_NPROP
# Londrina_NPROP
# para_PREP
# cobrar_V
# de_PREP|+
# o_ART
# ministro_N
# de_PREP|+
# a_ART
# Agricultura_N
# ,_,
# Synval_NPROP
# Guazzelli_NPROP
# ,_,
# um_ART
# novo_ADJ
# modelo_N
# de_PREP
# política_N
# agrícola_ADJ
# ,_,
# capaz_ADJ
# de_PREP
# estimular_V
# investimentos_N
# e_KC
# o_ART
# crescimento_N
# de_PREP|+
# a_ART
# produção_N
# ._.
# Antonio_NPROP
# Ambrósio_NPROP
# Amaro_NPROP
# é_V
# o_ART
# novo_ADJ
# diretor_N
# de_PREP|+
# o_ART
# Instituto_NPROP
# de_NPROP
# Economia_NPROP
# Agrícola_NPROP
# da_NPROP
# Secretaria_NPROP
# de_NPROP
# Agricultura_NPROP
# e_NPROP
# Abastecimento_NPROP
# de_NPROP
# São_NPROP
# Paulo_NPROP
# ._.
# Ele_PROPESS
# substitui_V
# Pérsio_NPROP
# de_NPROP
# Carvalho_NPROP
# Junqueira_NPROP
# ,_,
# que_PRO-KS-REL
# se_PROPESS
# aposentou_V
# após_PREP
# 34_NUM
# anos_N
# de_PREP
# serviço_N
# pesquisador_N
# científico_ADJ
# ._.
# As_ART
# doenças_N
# que_PRO-KS-REL
# estão_VAUX
# atacando_V
# as_ART
# lavouras_N
# gaúchas_ADJ
# de_PREP
# soja_N
# podem_VAUX
# ocasionar_V
# a_ART
# extinção_N
# de_PREP|+
# a_ART
# cultura_N
# em_PREP|+
# o_ART
# Estado_N
# ._.
# O_ART
# alerta_N
# é_V
# de_PREP|+
# o_ART
# pesquisador_N
# Nelson_NPROP
# Neto_NPROP
# ,_,
# de_PREP
# Cruz_NPROP
# Alta_NPROP
# ,_,
# que_PRO-KS-REL
# participou_V
# em_PREP|+
# a_ART
# semana_N
# passada_PCP
# de_PREP|+
# o_ART
# Forum_NPROP
# Nacional_NPROP
# da_NPROP
# Soja_NPROP
# em_PREP
# Porto_NPROP
# Alegre_NPROP
# ._.
# Em_PREP|+
# o_ART
# decorrer_N
# de_PREP|+
# os_ART
# últimos_ADJ
# três_NUM
# anos_N
# ,_,
# a_ART
# legislação_N
# tributária_ADJ
# rural_ADJ
# brasileira_ADJ
# vem_VAUX
# passando_V
# por_PREP
# sucessivas_ADJ
# reformas_N
# ._.
# Por_PREP|+
# o_ART
# conteúdo_N
# de_PREP
# cada_PROADJ
# nova_ADJ
# lei_N
# que_PRO-KS-REL
# entra_V
# em_PREP
# vigor_N
# ,_,
# nota_V|+
# se_PROPESS
# um_ART
# aperfeiçoamento_N
# de_PREP|+
# a_ART
# malha_N
# jurídica_ADJ
# em_PREP|+
# essa_PROADJ
# área_N
# e_KC
# também_PDEN
# o_ART
# afunilamento_N
# de_PREP|+
# o_ART
# cerco_N
# fiscal_ADJ
# em_PREP
# torno_PREP
# de_PREP
# o_ART
# contribuinte_N
# ._.
# Exemplo_N
# de_PREP|+
# isso_PROSUB
# é_V
# a_ART
# nova_ADJ
# lei_N
# de_PREP|+
# o_ART
# ITR_NPROP
# (_(
# nº_N
# 8.847/94_N|AP
# )_)
# ,_,
# que_PRO-KS-REL
# criou_V
# o_ART
# Cadastro_NPROP
# Fiscal_NPROP
# dos_NPROP
# Imóveis_NPROP
# Rurais_NPROP
# da_NPROP
# Secretaria_NPROP
# da_NPROP
# Receita_NPROP
# Federal_NPROP
# -_-
# Cafir_NPROP
# ._.
# Essa_PROADJ
# fúria_N
# fiscalista_ADJ
# começou_V
# em_PREP|+
# o_ART
# governo_N
# Collor_NPROP
# ,_,
# com_PREP
# a_ART
# lei_N
# 8.022/90_N|AP
# ,_,
# que_PRO-KS-REL
# passou_V
# para_PREP
# a_ART
# competência_N
# de_PREP|+
# a_ART
# o_ART
# lançamento_N
# e_KC
# a_ART
# arrecadação_N
# de_PREP|+
# o_ART
# ITR_NPROP
# ,_,
# que_PRO-KS-REL
# antes_ADV
# era_V
# de_PREP|+
# o_ART
# Incra_NPROP
# ._.
# Ainda_ADV
# em_PREP
# dezembro_N
# de_PREP
# 1990_N
# ,_,
# foi_VAUX
# editada_PCP
# a_ART
# famosa_ADJ
# 289_N|AP
# ,_,
# que_PRO-KS-REL
# modificava_V
# a_ART
# sistemática_N
# de_PREP|+
# a_ART
# arrecadação_N
# de_PREP|+
# o_ART
# ITR_NPROP
# e_KC
# alterava_V
# suas_PROADJ
# alíquotas_N
# ._.
# Mantinha_V
# a_ART
# tabela_N
# progressiva_ADJ
# ,_,
# mas_KC
# reduzia_V
# suas_PROADJ
# escalas_N
# por_PREP|+
# a_ART
# metade_N
# ._.
# A_ART
# atual_ADJ
# lei_N
# de_PREP|+
# o_ART
# ITR_NPROP
# é_V
# basicamente_ADV
# uma_ART
# cópia_N
# melhorada_PCP
# de_PREP|+
# essa_PROADJ
# medida_NPROP
# provisória_NPROP
# ,_,
# com_PREP
# a_ART
# extinção_N
# de_PREP|+
# a_ART
# tabela_N
# progressiva_ADJ
# e_KC
# a_ART
# criação_N
# de_PREP|+
# o_ART
# novo_ADJ
# cadastro_N
# ._.
# O_ART
# embrião_N
# de_PREP|+
# esse_PROADJ
# cadastro_N
# foi_V
# a_ART
# Portaria_N
# 1.275/91_N|AP
# ._.
# Ela_PROPESS
# criou_V
# a_ART
# Declaração_NPROP
# Anual_NPROP
# de_NPROP
# Informações_NPROP
# para_PREP
# a_ART
# Formação_NPROP
# do_NPROP
# Cadastro_NPROP
# Fiscal_NPROP
# do_NPROP
# Imposto_NPROP
# Territorial_NPROP
# Rural_NPROP
# -_-
# DITR_NPROP
# ._.
# Em_PREP|+
# a_ART
# prática_N
# ,_,
# isso_PROSUB
# correspondia_V
# a_PREP|+
# o_ART
# antigo_ADJ
# recadastramento_N
# de_PREP|+
# o_ART
# Incra_NPROP
# (_(
# devia_VAUX
# ser_VAUX
# feito_PCP
# a_PREP
# cada_PROADJ
# cinco_NUM
# anos_N
# ,_,
# mas_KC
# não_ADV
# se_PROPESS
# realizava_V
# desde_PREP
# 1978_N
# )_)
# ._.
# Os_ART
# técnicos_N
# de_PREP|+
# a_ART
# Receita_NPROP
# dizem_V
# que_KS
# a_ART
# Portaria_N
# 1.275_N|AP
# revelou_V
# um_ART
# novo_ADJ
# quadro_N
# de_PREP|+
# a_ART
# situação_N
# fundiária_ADJ
# de_PREP|+
# o_ART
# país_N
# ._.
# Segundo_PREP
# eles_PROPESS
# ,_,
# 75_NUM
# %_N
# de_PREP|+
# as_ART
# propriedades_N
# rurais_ADJ
# foram_VAUX
# recadastradas_PCP
# através_PREP|+
# de_PREP|+
# ela_PROPESS
# ._.
# Isso_PROSUB
# foi_V
# possível_ADJ
# por_PREP|+
# a_ART
# confrontação_N
# de_PREP|+
# os_ART
# dados_N
# cadastrais_ADJ
# de_PREP|+
# o_ART
# Incra_NPROP
# ,_,
# de_PREP|+
# o_ART
# DITR_NPROP
# e_KC
# de_PREP|+
# o_ART
# ._.
# Assim_ADV
# ,_,
# já_ADV
# podem_VAUX
# ser_VAUX
# identificados_PCP
# os_ART
# proprietários_N
# omissos_ADJ
# ._.
# Mas_KC
# advertem_V
# :_:
# agora_ADV
# ,_,
# quem_PRO-KS
# lança_V
# ,_,
# arrecada_V
# e_KC
# executa_V
# o_ART
# ITR_NPROP
# é_V
# o_ART
# Departamento_N
# de_PREP
# a_ART
# Receita_NPROP
# Federal_NPROP
# ,_,
# que_PRO-KS-REL
# tem_V
# estrutura_N
# fiscal_ADJ
# sólida_ADJ
# e_KC
# faro_N
# afinado_PCP
# para_PREP
# descobrir_V
# sonegadores_N
# ._.
# Segundo_PREP
# Paulo_NPROP
# Jakson_NPROP
# Lucas_NPROP
# ,_,
# auditor_N
# chefe_N
# de_PREP|+
# o_ART
# ITR_NPROP
# em_PREP
# São_NPROP
# Paulo_NPROP
# ,_,
# embora_KS
# o_ART
# prazo_N
# para_PREP
# a_ART
# entrega_N
# de_PREP|+
# a_ART
# declaração_N
# tenha_VAUX
# vencido_PCP
# em_PREP
# maio_N
# de_PREP
# 1992_N
# ,_,
# até_PREP
# hoje_ADV
# o_ART
# órgão_N
# ainda_ADV
# continua_VAUX
# recebendo_V
# ._.
# Mas_KC
# os_ART
# retardatários_N
# incorrerão_V
# em_PREP
# multa_N
# de_PREP
# 100_NUM
# %_N
# e_KC
# os_ART
# omissos_N
# serão_VAUX
# lançados_PCP
# de_PREP
# ofício_N
# com_PREP
# os_ART
# dados_N
# disponíveis_ADJ
# e_KC
# com_PREP
# multa_N
# de_PREP
# 300_NUM
# %_N
# ._.
# Sobre_PREP
# o_ART
# montante_N
# apurado_PCP
# ,_,
# incidirão_V
# juros_N
# de_PREP
# lei_N
# e_KC
# correção_N
# monetária_ADJ
# plena_ADJ
# ,_,
# acrescentou_V
# ._.
# Por_PREP|+
# as_ART
# múltiplas_ADJ
# opções_N
# de_PREP
# enquadramento_N
# que_PRO-KS-REL
# a_ART
# nova_ADJ
# lei_N
# oferece_V
# ,_,
# o_ART
# proprietário_N
# rural_ADJ
# deve_VAUX
# refazer_V
# a_ART
# sua_PROADJ
# declaração_N
# cadastral_ADJ
# ._.
# Ele_PROPESS
# poderá_VAUX
# remanejar_V
# seus_PROADJ
# dados_N
# para_PREP
# enquadramento_N
# em_PREP
# alíquotas_N
# reduzidas_PCP
# ._.
# O_ART
# Cafir_NPROP
# fechou_V
# também_PDEN
# mais_PROADJ
# uma_NUM
# porteira_N
# de_PREP
# sonegação_N
# fiscal_ADJ
# em_PREP|+
# o_ART
# setor_N
# fundiário_ADJ
# ._.
# Agora_ADV
# ,_,
# nenhum_PROADJ
# cartório_N
# poderá_VAUX
# registrar_V
# quaisquer_PROADJ
# negócios_N
# ,_,
# operações_N
# ou_KC
# transações_N
# de_PREP
# imóveis_N
# rurais_ADJ
# sem_PREP
# o_ART
# comprovante_N
# de_PREP
# quitação_N
# de_PREP|+
# o_ART
# ITR_NPROP
# ._.
# O_ART
# tabelião_N
# que_PRO-KS-REL
# não_ADV
# cumprir_V
# a_ART
# lei_N
# ,_,
# responsabilizado_PCP
# ._.
# Augusto_NPROP
# Ribeiro_NPROP
# Garcia_NPROP
# é_V
# jornalista_N
# ,_,
# advogado_N
# agrarista_ADJ
# e_KC
# membro_N
# de_PREP|+
# o_ART
# Instituto_NPROP
# Paulista_NPROP
# de_NPROP
# Direito_NPROP
# Agrário_NPROP
# ._.
# Embora_KS
# com_PREP
# a_ART
# redução_N
# de_PREP|+
# as_ART
# chuvas_N
# ,_,
# a_ART
# maioria_N
# de_PREP|+
# os_ART
# locais_N
# se_PROPESS
# manteve_V
# com_PREP
# a_ART
# reserva_N
# hídrica_ADJ
# elevada_PCP
# ,_,
# favorecendo_V
# as_ART
# culturas_N
# cultivadas_PCP
# sob_PREP
# sequeiro_N
# ._.
# As_ART
# condições_N
# de_PREP
# colheita_N
# e_KC
# de_PREP
# aplicação_N
# de_PREP
# agrotóxicos_N
# foram_VAUX
# favorecidas_PCP
# em_PREP|+
# a_ART
# última_ADJ
# semana_N
# ,_,
# principalmente_ADV
# para_PREP
# arroz_N
# ,_,
# aldogão_N
# e_KC
# milho_N
# ._.
# A_ART
# irrigação_N
# suplementar_ADJ
# é_V
# necessária_ADJ
# para_PREP
# as_ART
# culturas_N
# sob_PREP
# sequeiro_N
# ._.
# Porém_KC
# ,_,
# como_KS
# a_ART
# previsão_N
# indica_V
# entrada_N
# de_PREP
# frente_N
# fria_ADJ
# ,_,
# deve_VAUX|+
# se_PROPESS
# aguardar_V
# até_PREP
# quarta-feira_N
# e_KC
# irrigar_V
# somente_PDEN
# se_KS
# o_ART
# total_N
# de_PREP
# chuva_N
# for_V
# inferior_ADJ
# a_PREP
# 30_NUM
# mm_N
# ._.
# Os_ART
# plantios_N
# de_PREP
# culturas_N
# adequadas_PCP
# a_PREP|+
# a_ART
# época_N
# ,_,
# como_PREP
# milho_N
# safrinha_ADJ
# e_KC
# feijão_N
# de_PREP
# inverno_N
# ,_,
# podem_VAUX
# ser_VAUX
# realizados_PCP
# em_PREP|+
# as_ART
# regiões_N
# e_KC
# nordeste_ADJ
# de_PREP|+
# o_ART
# Estado_N
# ._.
# A_ART
# reserva_N
# hídrica_ADJ
# é_V
# suficiente_ADJ
# para_PREP
# garantir_V
# o_ART
# sucesso_N
# inicial_ADJ
# de_PREP|+
# as_ART
# culturas_N
# ._.
# Em_PREP|+
# as_ART
# regiões_N
# sudoeste_ADJ
# e_KC
# Vale_NPROP
# do_NPROP
# Paranapanema_NPROP
# ,_,
# o_ART
# plantio_N
# de_PREP
# milho_N
# safrinha_ADJ
# não_ADV
# deve_VAUX
# mais_ADV
# ser_VAUX
# realizado_PCP
# ._.
# Há_V
# probabilidade_N
# de_PREP
# ser_VAUX
# afetado_PCP
# por_PREP|+
# as_ART
# baixas_ADJ
# temperaturas_N
# ,_,
# além_PREP|+
# de_PREP|+
# o_ART
# ciclo_N
# tornar_V|+
# se_PROPESS
# longo_ADJ
# ._.
# O_ART
# preparo_N
# de_PREP|+
# o_ART
# solo_N
# e_KC
# demais_PROADJ
# atividades_N
# para_PREP
# o_ART
# plantio_N
# de_PREP
# culturas_N
# de_PREP
# inverno_N
# ,_,
# como_PREP
# trigo_N
# e_KC
# ervilha_N
# ,_,
# podem_VAUX
# ser_VAUX
# iniciados_PCP
# ._.
# As_ART
# culturas_N
# perenes_ADJ
# estão_VAUX
# sendo_VAUX
# favorecidas_PCP
# ,_,
# principalmente_ADV
# em_PREP|+
# a_ART
# colheita_N
# como_PREP
# citrus_N
# ,_,
# cana_N
# e_KC
# café_N
# ._.
# Venda_N
# de_PREP
# máquina_N
# agrícola_ADJ
# cresce_V
# 70_NUM
# %_N
# ._.
# Venda_N
# de_PREP
# máquina_N
# agrícola_ADJ
# cresce_V
# 70_NUM
# %_N
# ._.
# As_ART
# vendas_N
# de_PREP|+
# as_ART
# máquinas_N
# agrícolas_ADJ
# -_-
# trator_N
# ,_,
# colheitadeira_N
# e_KC
# cultivador_N
# cresceram_V
# 70,39_NUM
# %_N
# em_PREP|+
# o_ART
# primeiro_ADJ
# trimestre_N
# de_PREP
# 94_N
# em_PREP
# comparação_N
# com_PREP
# o_ART
# período_N
# de_PREP
# 93_N
# ._.
# De_PREP
# janeiro_N
# a_PREP
# março_N
# ,_,
# o_ART
# mercado_N
# interno_ADJ
# comprou_V
# 7.676_NUM
# máquinas_N
# ._.
# Em_PREP|+
# o_ART
# período_N
# de_PREP
# 93_N
# ,_,
# foram_VAUX
# vendidas_PCP
# 4.505_NUM
# unidades_N
# ._.
# Os_ART
# dados_N
# são_V
# de_PREP|+
# a_ART
# Anfavea_NPROP
# -_-
# a_ART
# associação_N
# que_PRO-KS-REL
# reúne_V
# as_ART
# montadoras_N
# ._.
# Pérsio_NPROP
# Pastre_NPROP
# ,_,
# vice-presidente_N
# de_PREP|+
# a_ART
# Anfavea_NPROP
# ,_,
# afirma_V
# que_KS
# o_ART
# aumento_N
# de_PREP|+
# as_ART
# vendas_N
# é_V
# consequência_N
# de_PREP
# uma_ART
# "_"
# combinação_N
# feliz_ADJ
# "_"
# entre_PREP
# produção_N
# ,_,
# preço_N
# ,_,
# financiamento_N
# agrícola_ADJ
# e_KC
# crescimento_N
# econômico_ADJ
# ._.
# Pastre_NPROP
# afirma_V
# que_KS
# a_ART
# grande_ADJ
# safra_N
# -_-
# de_PREP
# 73,6_NUM
# milhões_N
# de_PREP
# toneladas_N
# de_PREP
# grãos_N
# segundo_PREP
# a_ART
# Companhia_NPROP
# Nacional_NPROP
# de_NPROP
# Abastecimento_NPROP
# (_(
# Conab_NPROP
# )_)
# -_-
# incentiva_V
# os_ART
# agricultores_N
# a_PREP
# investirem_V
# em_PREP|+
# a_ART
# produção_N
# ._.
# "_"
# O_ART
# preço_N
# agrícola_ADJ
# está_V
# favorável_ADJ
# a_PREP|+
# o_ART
# agricultor_N
# ,_,
# remunerando_V
# a_ART
# sua_PROADJ
# produção_N
# ,_,
# e_KC
# há_V
# garantia_N
# de_PREP
# financiamento_N
# "_"
# ,_,
# diz_V
# Pastre_NPROP
# ._.
# Atualmente_ADV
# há_V
# US$_CUR
# 650_NUM
# milhões_N
# de_PREP|+
# o_ART
# Finame_NPROP
# Agrícola_NPROP
# (_(
# linha_N
# de_PREP
# crédito_N
# de_PREP|+
# o_ART
# BNDES_NPROP
# )_)
# para_PREP
# o_ART
# financiamento_N
# de_PREP|+
# a_ART
# compra_N
# de_PREP
# máquinas_N
# ._.
# O_ART
# volume_N
# de_PREP
# recursos_N
# para_PREP
# 95_N
# deverá_VAUX
# chegar_V
# a_PREP
# US$_CUR
# 880_NUM
# milhões_N
# ._.
# "_"
# A_ART
# disponibilidade_N
# de_PREP
# recursos_N
# é_V
# mais_PROADJ
# uma_NUM
# garantia_N
# a_PREP|+
# o_ART
# agricultor_N
# ,_,
# que_PRO-KS-REL
# está_V
# com_PREP
# máquinas_N
# antigas_ADJ
# "_"
# ,_,
# lembra_V
# Pastre_NPROP
# ._.
# A_ART
# falta_N
# de_PREP
# financiamento_N
# ,_,
# segundo_PREP
# a_ART
# Anfavea_NPROP
# ,_,
# foi_V
# a_ART
# principal_ADJ
# causa_N
# de_PREP|+
# a_ART
# redução_N
# de_PREP
# vendas_N
# em_PREP
# 92_N
# ,_,
# quando_ADV-KS-REL
# foram_VAUX
# comercializadas_PCP
# 12_NUM
# mil_NUM
# unidades_N
# ._.
# Com_PREP
# o_ART
# resultado_N
# de_PREP|+
# o_ART
# primeiro_ADJ
# trimestre_N
# ,_,
# a_ART
# Anfavea_NPROP
# estima_V
# que_KS
# o_ART
# total_N
# de_PREP|+
# as_ART
# vendas_N
# de_PREP
# 94_N
# será_V
# 30_NUM
# %_N
# o_ART
# registrado_N
# em_PREP
# 93_N
# ._.
# Em_PREP|+
# os_ART
# tratores_N
# ,_,
# o_ART
# movimento_N
# de_PREP
# janeiro_N
# a_PREP
# março_N
# representa_V
# 20_NUM
# %_N
# de_PREP|+
# as_ART
# vendas_N
# de_PREP|+
# o_ART
# ano_N
# ._.
# Com_PREP
# 5.774_NUM
# unidades_N
# comercializadas_PCP
# em_PREP|+
# esse_PROADJ
# primeiro_ADJ
# trimestre_N
# ,_,
# a_ART
# previsão_N
# é_V
# de_PREP
# vender_V
# 28_NUM
# mil_NUM
# em_PREP
# 94_N
# ._.
# "_"
# O_ART
# crescimento_N
# é_V
# expressivo_ADJ
# mas_KC
# ,_,
# mesmo_PDEN
# assim_PDEN
# ,_,
# estamos_V
# abaixo_PREP|+
# de_PREP|+
# a_ART
# média_ADJ
# história_N
# de_PREP|+
# o_ART
# setor_N
# ,_,
# que_PRO-KS-REL
# é_V
# de_PREP
# 45_NUM
# mil_NUM
# tratores_N
# por_PREP
# ano_N
# "_"
# ,_,
# diz_V
# Pastre_NPROP
# ._.
# Em_PREP|+
# as_ART
# colheitadeiras_N
# ,_,
# foram_VAUX
# vendidas_PCP
# 1.543_NUM
# máquinas_N
# em_PREP|+
# este_PROADJ
# primeiro_ADJ
# trimestre_N
# ,_,
# período_N
# que_PRO-KS-REL
# corresponde_V
# ,_,
# normalmente_ADV
# ,_,
# a_PREP
# 40_NUM
# %_N
# de_PREP|+
# o_ART
# movimento_N
# anual_ADJ
# ._.
# A_ART
# previsão_N
# vender_V
# 3.800_NUM
# colheitadeiras_N
# em_PREP
# 94_N
# ,_,
# contra_PREP
# as_ART
# 2.735_N
# de_PREP|+
# o_ART
# ano_N
# passado_PCP
# ._.
# As_ART
# vendas_N
# de_PREP
# colheitadeiras_N
# se_PROPESS
# concentram_V
# entre_PREP
# outubro_N
# e_KC
# março_N
# ._.
# Mas_KC
# Pastre_NPROP
# acredita_V
# que_KS
# ,_,
# como_KS
# o_ART
# agricultor_N
# está_V
# capitalizado_PCP
# ,_,
# ele_PROPESS
# deve_VAUX
# continuar_VAUX
# comprando_V
# o_ART
# equipamento_N
# em_PREP|+
# os_ART
# demais_PROADJ
# meses_N
# de_PREP|+
# o_ART
# ano_N
# ._.
# "_"
# A_ART
# retração_N
# de_PREP|+
# as_ART
# vendas_N
# em_PREP
# abril_N
# ,_,
# que_PRO-KS-REL
# costuma_VAUX
# ocorrer_V
# por_PREP|+
# a_ART
# sazonalidade_N
# ,_,
# deverá_VAUX
# ser_V
# menor_ADJ
# esse_PROADJ
# ano_N
# "_"
# ,_,
# afirma_V
# ._.
# As_ART
# exportações_N
# de_PREP
# máquinas_N
# também_PDEN
# cresceram_V
# ,_,
# passando_V
# de_PREP
# US$_CUR
# 60_NUM
# milhões_N
# em_PREP|+
# o_ART
# primeiro_ADJ
# trimestre_N
# de_PREP
# 93_N
# para_PREP
# US$_CUR
# 90_NUM
# milhões_N
# em_PREP|+
# o_ART
# período_N
# de_PREP
# 94_N
# ._.
# A_ART
# Argentina_NPROP
# é_V
# o_ART
# principal_ADJ
# mercado_N
# ._.
# A_ART
# fabricante_N
# New_NPROP
# Holland_NPROP
# ,_,
# de_PREP|+
# o_ART
# grupo_N
# Fiat_NPROP
# ,_,
# foi_V
# a_ART
# empresa_N
# que_PRO-KS-REL
# mais_ADV
# cresceu_V
# em_PREP
# vendas_N
# em_PREP
# março_N
# ._.
# Suas_PROADJ
# vendas_N
# de_PREP
# tratores_N
# e_KC
# colheitadeira_N
# foram_V
# ,_,
# respectivamente_ADV
# ,_,
# 174_NUM
# %_N
# e_KC
# 72_NUM
# %_N
# maiores_ADJ
# em_PREP|+
# esse_PROADJ
# primeiro_ADJ
# trimeste_N
# de_PREP
# 94_N
# com_PREP
# o_ART
# igual_ADJ
# período_N
# de_PREP|+
# o_ART
# ano_N
# passado_PCP
# ._.
# "_"
# A_ART
# empresa_N
# modernizou_V
# a_ART
# linha_N
# de_PREP
# produtos_N
# e_KC
# aumentou_V
# a_ART
# potência_N
# média_ADJ
# de_PREP|+
# as_ART
# máquinas_N
# "_"
# ,_,
# diz_V
# Pastre_NPROP
# ,_,
# que_PRO-KS-REL
# também_PDEN
# é_V
# diretor_ADJ
# de_PREP|+
# a_ART
# empresa_N
# ._.
# A_ART
# Iochpe-Maxion_NPROP
# ,_,
# líder_N
# de_PREP|+
# o_ART
# setor_N
# ,_,
# vai_VAUX
# investir_V
# US$_CUR
# 40_NUM
# milhões_N
# em_PREP|+
# os_ART
# próximos_ADJ
# três_NUM
# anos_N
# em_PREP|+
# a_ART
# modernização_N
# industrial_ADJ
# ,_,
# treinamento_N
# e_KC
# novos_ADJ
# produtos_N
# ._.
# "_"
# Os_ART
# clientes_N
# estão_VAUX
# procurando_V
# produtos_N
# mais_ADV
# específicos_ADJ
# as_PREP
# suas_PROADJ
# necessidades_N
# "_"
# ,_,
# diz_V
# Paulo_NPROP
# Saraiva_NPROP
# ,_,
# diretor_N
# de_PREP|+
# a_ART
# empresa_N
# ._.
# De_PREP
# janeiro_N
# a_PREP
# a_ART
# março_N
# ,_,
# a_ART
# empresa_N
# vendeu_V
# 2.789_NUM
# tratores_N
# de_PREP
# roda_N
# -_-
# 1.549_N
# apenas_PDEN
# em_PREP
# março_N
# ._.
# O_ART
# governo_N
# de_PREP
# Mato_NPROP
# Grosso_NPROP
# do_NPROP
# Sul_NPROP
# está_VAUX
# premiando_V
# os_ART
# agricultores_N
# que_PRO-KS-REL
# alcançarem_V
# produtivade_N
# agrícola_ADJ
# acima_PREP|+
# de_PREP|+
# a_ART
# média_N
# estadual_ADJ
# ._.
# O_ART
# prêmio_N
# é_V
# a_ART
# restituição_N
# de_PREP|+
# o_ART
# valor_N
# de_PREP|+
# o_ART
# ICMS_NPROP
# (_(
# Imposto_NPROP
# Sobre_NPROP
# Circulação_NPROP
# de_NPROP
# Mercadorias_NPROP
# e_NPROP
# Serviços_NPROP
# )_)
# a_PREP|+
# a_ART
# parcela_N
# que_PRO-KS-REL
# superou_V
# a_ART
# média_N
# ._.
# É_VAUX
# concedido_PCP
# por_PREP|+
# o_ART
# programa_N
# Terra_NPROP
# Viva_NPROP
# ._.
# Segundo_PREP
# o_ART
# secretário_N
# de_PREP
# Agricultura_NPROP
# do_NPROP
# Estado_NPROP
# ,_,
# José_NPROP
# Américo_NPROP
# Flores_NPROP
# do_NPROP
# Amaral_NPROP
# ,_,
# em_PREP
# 93_N
# foram_VAUX
# devolvidos_PCP
# a_PREP|+
# os_ART
# produtores_N
# cadastrados_PCP
# cerca_PREP
# de_PREP
# US$_CUR
# 9_NUM
# milhões_N
# ._.
# Para_PREP
# esta_PROADJ
# safra_N
# ,_,
# a_ART
# previsão_N
# é_V
# de_PREP
# que_KS
# o_ART
# volume_N
# de_PREP
# restituições_N
# atinja_V
# US$_CUR
# 12_NUM
# milhões_N
# ._.
# Flores_NPROP
# do_NPROP
# Amaral_NPROP
# diz_V
# que_KS
# esta_PROSUB
# foi_V
# a_ART
# forma_N
# encontrada_PCP
# para_PREP
# evitar_V
# que_KS
# a_ART
# produtividade_N
# e_KC
# a_ART
# área_N
# agrícola_ADJ
# de_PREP|+
# o_ART
# Estado_N
# continuassem_V
# em_PREP
# ritmo_N
# decrescente_ADJ
# ,_,
# vinha_VAUX
# acontecendo_V
# em_PREP|+
# os_ART
# últimos_ADJ
# anos_N
# ._.
# Para_PREP
# ele_PROPESS
# ,_,
# um_ART
# indicativo_N
# que_KS
# o_ART
# programa_N
# está_VAUX
# dando_V
# certo_ADJ
# é_V
# que_KS
# em_PREP|+
# esta_PROADJ
# safra_N
# a_ART
# área_N
# deve_VAUX
# aumentar_V
# 3_NUM
# %_N
# e_KC
# a_ART
# produtividade_N
# ,_,
# 7_NUM
# %_N
# ._.
# Segundo_PREP
# a_ART
# ,_,
# para_PREP
# a_ART
# safra_N
# 93/94_N|AP
# se_PROPESS
# inscreveram_V
# 1.626_NUM
# produtores_N
# ,_,
# com_PREP
# área_N
# plantada_PCP
# de_PREP
# 426_NUM
# mil_NUM
# hectares_N
# ._.
# A_ART
# previsão_N
# é_V
# que_KS
# a_ART
# produção_N
# de_PREP|+
# as_ART
# seis_NUM
# principais_ADJ
# culturas_N
# atendidas_PCP
# por_PREP|+
# o_ART
# programa_N
# (_(
# algodão_N
# ,_,
# arroz_N
# irrigado_PCP
# e_KC
# de_PREP
# sequeiro_N
# ,_,
# mandioca_N
# ,_,
# milho_N
# e_KC
# soja_N
# )_)
# alcance_V
# 1,35_NUM
# milhão_N
# de_PREP
# t_N
# ,_,
# de_PREP|+
# os_PRO-KS-REL
# quais_PRO-KS-REL
# 26_NUM
# %_N
# (_(
# 357,7_NUM
# mil_NUM
# t_N
# )_)
# serão_VAUX
# incentivadas_PCP
# ._.
# O_ART
# programa_N
# atende_V
# ainda_ADV
# as_ART
# culturas_N
# de_PREP
# feijão_N
# (_(
# primeira_ADJ
# e_KC
# segunda_ADJ
# safras_N
# )_)
# ,_,
# arroz_N
# de_PREP
# várzea_N
# e_KC
# mamona_N
# ,_,
# cujas_PRO-KS-REL
# estimativas_N
# de_PREP
# produção_N
# ainda_ADV
# não_ADV
# foram_VAUX
# elaboradas_PCP
# ._.
# O_ART
# relatório_N
# de_PREP|+
# a_ART
# Secretaria_NPROP
# considerou_V
# apenas_PDEN
# os_ART
# produtores_N
# de_PREP|+
# as_ART
# seis_NUM
# principais_ADJ
# culturas_N
# ,_,
# com_PREP
# as_ART
# respectivas_ADJ
# áreas_N
# cadastradas_PCP
# e_KC
# que_PRO-KS-REL
# se_PROPESS
# inscreveram_V
# em_PREP|+
# o_ART
# programa_N
# ._.
# A_ART
# Kasper_NPROP
# e_NPROP
# Companhia_NPROP
# ,_,
# que_PRO-KS-REL
# tem_V
# cerca_PREP
# de_PREP
# 8.000_NUM
# ha_N
# de_PREP
# soja_N
# ,_,
# milho_N
# e_KC
# arroz_N
# de_PREP
# sequeiro_N
# em_PREP
# São_NPROP
# Gabriel_NPROP
# D'_NPROP
# Oeste_NPROP
# $_$
# (_(
# 138_NUM
# km_N
# a_PREP|+
# o_ART
# norte_N
# de_PREP
# Campo_NPROP
# Grande_NPROP
# )_)
# e_KC
# Chapadão_NPROP
# do_NPROP
# Sul_NPROP
# (_(
# 336_NUM
# km_N
# de_PREP
# Campo_NPROP
# Grande_NPROP
# )_)
# ,_,
# ampliou_V
# sua_PROADJ
# área_N
# de_PREP
# produção_N
# em_PREP
# 400_NUM
# hectares_N
# em_PREP|+
# a_ART
# safra_N
# passada_PCP
# e_KC
# está_VAUX
# incorporando_V
# mais_PROADJ
# 670_NUM
# hectares_N
# em_PREP|+
# a_ART
# safra_N
# 93/94_N|AP
# ,_,
# segundo_PREP
# seu_PROADJ
# diretor_N
# ,_,
# Jorge_NPROP
# Kasper_NPROP
# ._.
# O_ART
# gerente_N
# técnico_ADJ
# de_PREP|+
# a_ART
# cooperativa_N
# ,_,
# Márcio_NPROP
# Portocarrero_NPROP
# ,_,
# diz_V
# que_KS
# já_ADV
# se_PROPESS
# pode_VAUX
# perceber_V
# um_ART
# volume_N
# maior_ADJ
# de_PREP
# investimentos_N
# em_PREP|+
# o_ART
# controle_N
# de_PREP
# pragas_N
# ,_,
# conservação_N
# de_PREP|+
# o_ART
# solo_N
# e_KC
# busca_N
# de_PREP
# tecnologias_N
# para_PREP
# aumento_N
# de_PREP|+
# a_ART
# produtividade_N
# ._.
# A_ART
# praga_N
# de_PREP
# gafanhotos_N
# que_PRO-KS-REL
# ataca_V
# os_ART
# canaviais_N
# de_PREP|+
# a_ART
# Paraíba_NPROP
# está_VAUX
# atingindo_V
# as_ART
# lavouras_N
# de_PREP
# feijão_N
# e_KC
# milho_N
# e_KC
# os_ART
# plantios_N
# de_PREP
# abacaxi_N
# de_PREP|+
# o_ART
# Estado_N
# ._.
# Segundo_PREP
# o_ART
# delegado_N
# de_PREP|+
# o_ART
# em_PREP|+
# o_ART
# Estado_N
# ,_,
# Augusto_NPROP
# Bezerra_NPROP
# ,_,
# até_PREP
# quarta-feira_N
# passada_PCP
# a_ART
# praga_N
# tinha_VAUX
# atingido_PCP
# 110_NUM
# mil_NUM
# ha_N
# em_PREP
# 40_NUM
# municípios_N
# em_PREP|+
# as_ART
# regiões_N
# de_PREP|+
# o_ART
# brejo_N
# ,_,
# litoral_N
# e_KC
# Zona_NPROP
# da_NPROP
# Mata_NPROP
# ._.
# O_ART
# liberou_V
# há_V
# duas_NUM
# semanas_N
# Cr$_CUR
# 120_NUM
# milhões_N
# para_PREP
# a_ART
# compra_N
# de_PREP
# inseticida_N
# ._.
# de_PREP
# acordo_PREP
# com_PREP
# Bezerra_NPROP
# ,_,
# o_ART
# dinheiro_N
# é_V
# suficiente_ADJ
# para_PREP
# a_ART
# compra_N
# de_PREP
# 13_NUM
# mil_NUM
# litros_N
# de_PREP
# veneno_N
# ,_,
# mas_KC
# o_ART
# volume_N
# necessário_ADJ
# é_V
# dez_NUM
# vezes_N
# maior_ADJ
# ._.
# Ele_PROPESS
# afirma_V
# que_KS
# a_ART
# praga_N
# já_ADV
# atinge_V
# canaviais_N
# de_PREP|+
# o_ART
# Rio_NPROP
# Grande_NPROP
# do_NPROP
# Norte_NPROP
# e_KC
# Pernambuco_NPROP
# ._.
# Bezerra_NPROP
# diz_V
# que_KS
# está_VAUX
# articular_V
# uma_ART
# ação_N
# conjunta_ADJ
# de_PREP|+
# o_ART
# com_PREP
# os_ART
# governos_N
# de_PREP|+
# os_ART
# três_NUM
# Estados_N
# para_PREP
# controlar_V
# a_ART
# praga_N
# ._.
# Técnicos_N
# em_PREP|+
# a_ART
# Paraíba_NPROP
# estão_VAUX
# levantando_V
# dados_N
# sobre_PREP
# a_ART
# destruição_N
# de_PREP|+
# as_ART
# lavouras_N
# ._.
# Eles_PROPESS
# sabem_V
# que_KS
# a_ART
# situação_N
# é_V
# mais_ADV
# grave_ADJ
# em_PREP|+
# os_ART
# canaviais_N
# de_PREP
# Mamanguape_NPROP
# e_KC
# Santa_NPROP
# Rita_NPROP
# ,_,
# em_PREP|+
# as_ART
# plantações_N
# de_PREP
# abacaxi_N
# de_PREP
# Araçagi_NPROP
# e_KC
# Itapororoca_NPROP
# e_KC
# em_PREP|+
# as_ART
# lavouras_N
# de_PREP
# milho_N
# e_KC
# feijão_N
# de_PREP
# Tacima_NPROP
# e_KC
# Araruna_NPROP
# ._.
# Segundo_PREP
# Bezerra_NPROP
# ,_,
# a_ART
# concentração_N
# de_PREP
# gafanhotos_N
# por_PREP
# metro_N
# quadrado_ADJ
# em_PREP|+
# a_ART
# Paraíba_NPROP
# é_V
# de_PREP
# 200_N
# ,_,
# o_ART
# ideal_N
# seria_V
# um_ART
# gafanhoto_N
# por_PREP
# metro_N
# quadrado_ADJ
# ._.
# Os_ART
# técnicos_N
# estão_VAUX
# recomendando_V
# que_KS
# os_ART
# grandes_ADJ
# fazendeiros_N
# e_KC
# usineiros_N
# iniciem_V
# o_ART
# combate_N
# a_PREP|+
# a_ART
# praga_N
# por_PREP
# conta_N
# ._.
# cem_NUM
# mil_NUM
# toneladas_N
# de_PREP
# sementes_N
# para_PREP
# pastagens_N
# são_VAUX
# produzidas_PCP
# e_KC
# consumidas_PCP
# anualmente_ADV
# em_PREP|+
# o_ART
# mercado_N
# interno_ADJ
# brasileiro_ADJ
# ._.
# Este_PROADJ
# comércio_N
# movimenta_V
# a_ART
# expressiva_ADJ
# soma_N
# de_PREP
# US$_CUR
# 250_NUM
# milhões_N
# a_PREP
# cada_PROADJ
# ano_N
# ,_,
# segundo_PREP
# estimativas_N
# de_PREP
# técnicos_N
# de_PREP|+
# a_ART
# Empresa_NPROP
# Brasileira_NPROP
# de_NPROP
# Pesquisa_NPROP
# Agropecuária_NPROP
# (_(
# Embrapa_NPROP
# )_)
# ._.
# É_V
# um_ART
# mercado_N
# hoje_ADV
# equivalente_ADJ
# a_PREP|+
# de_PREP|+
# o_ART
# milho_N
# híbrido_ADJ
# ._.
# E_KC
# que_KS
# tem_V
# ,_,
# 80_NUM
# %_N
# de_PREP|+
# a_ART
# comercialização_N
# centrada_PCP
# em_PREP|+
# um_ART
# único_ADJ
# capim_N
# :_:
# a_ART
# braquiaria_N
# (_(
# e_KC
# suas_PROADJ
# variedades_N
# )_)
# ._.
# Forrageira_N
# originária_ADJ
# de_PREP|+
# a_ART
# África_NPROP
# ,_,
# a_ART
# braquiaria_N
# foi_VAUX
# introduzida_PCP
# em_PREP|+
# o_ART
# país_N
# por_PREP|+
# a_ART
# Estação_NPROP
# Experimental_NPROP
# Norte_NPROP
# (_(
# PEAN_NPROP
# )_)
# de_PREP
# Belém_NPROP
# em_PREP
# 1962_N
# ._.
# Em_PREP
# pouco_ADV
# mais_PREP
# de_PREP
# 15_NUM
# anos_N
# ,_,
# a_ART
# braquiara_N
# tomou_V
# conta_N
# de_PREP|+
# o_ART
# país_N
# ._.
# Em_PREP|+
# esses_PROADJ
# quinze_NUM
# anos_N
# a_ART
# produção_N
# de_PREP
# sementes_N
# para_PREP
# pastagens_N
# se_PROPESS
# caracterizou_V
# um_ART
# mercado_N
# informal_ADJ
# ,_,
# pulverizado_PCP
# ,_,
# que_PRO-KS-REL
# convive_V
# com_PREP
# fiscalização_N
# frágil_ADJ
# ,_,
# concentrando_V
# milhares_N
# de_PREP
# empresas_N
# e_KC
# produtores_N
# individuais_ADJ
# ._.
# Assim_KS
# ,_,
# a_ART
# qualidade_N
# de_PREP|+
# a_ART
# semente_N
# colocada_PCP
# a_PREP|+
# a_ART
# disposição_N
# de_PREP|+
# o_ART
# pecuarista_N
# é_V
# ainda_ADV
# muito_ADV
# diferenciada_PCP
# ._.
# Em_PREP|+
# o_ART
# mercado_N
# internacional_ADJ
# a_ART
# "_"
# conversa_N
# é_V
# outra_PROSUB
# "_"
# ._.
# Empresas_N
# que_PRO-KS-REL
# não_ADV
# apresentam_V
# produtos_N
# com_PREP
# o_ART
# mínimo_N
# de_PREP
# 95_NUM
# %_N
# de_PREP
# valor_N
# cultural_ADJ
# (_(
# capacidade_N
# de_PREP
# germinação_N
# e_KC
# pureza_N
# )_)
# não_ADV
# conseguem_V
# comercializar_V
# a_ART
# sua_PROADJ
# produção_N
# ._.
# Para_PREP
# Francisco_NPROP
# Durban_NPROP
# de_NPROP
# Souza_NPROP
# ,_,
# técnico_N
# de_PREP|+
# o_ART
# Centro_NPROP
# Nacional_NPROP
# de_NPROP
# Pesquisas_NPROP
# de_NPROP
# Gado_NPROP
# de_NPROP
# Corte_NPROP
# -_-
# CNPGC-_NPROP
# de_PREP|+
# a_ART
# Embrapa_NPROP
# em_PREP
# Campo_NPROP
# Grande-_NPROP
# MS_NPROP
# ,_,
# um_PROSUB
# de_PREP|+
# os_ART
# principais_ADJ
# centros_N
# de_PREP
# pesquisa_N
# em_PREP
# forrageiras_N
# ,_,
# poucos_PROADJ
# produtores_N
# nacionais_ADJ
# têm_V
# capacidade_N
# hoje_ADV
# de_PREP
# absorver_V
# alta_ADJ
# tecnologia_N
# em_PREP|+
# o_ART
# plantio_N
# e_KC
# nem_ADV
# mesmo_PDEN
# há_V
# equipamentos_N
# para_PREP
# semeadura_N
# que_PRO-KS-REL
# permitam_V
# o_ART
# manuseio_N
# de_PREP
# sementes_N
# de_PREP
# alto_ADJ
# valor_N
# cultural_ADJ
# ._.
# Assim_KS
# fica_V
# o_ART
# pecuarista_N
# buscar_V
# qualidade_N
# em_PREP|+
# a_ART
# hora_N
# de_PREP|+
# a_ART
# compra_N
# ,_,
# embora_KS
# Durban_NPROP
# ressalte_V
# que_KS
# sementes_N
# com_PREP
# valor_N
# cultural_ADJ
# em_PREP
# torno_PREP
# de_PREP
# 45_NUM
# %_N
# (_(
# a_ART
# média_N
# hoje_ADV
# de_PREP|+
# o_ART
# mercado_N
# brasileiro_ADJ
# )_)
# ,_,
# dão_V
# resultados_N
# satisfatórios_ADJ
# para_PREP
# o_ART
# pecuarista_N
# ._.
# de_PREP
# qualquer_PROADJ
# maneira_N
# ,_,
# toda_PROADJ
# essa_PROADJ
# "_"
# informalidade_N
# "_"
# em_PREP|+
# a_ART
# produção_N
# de_PREP
# sementes_N
# não_ADV
# foi_V
# obstáculo_N
# a_PREP
# um_ART
# enorme_ADJ
# crescimento_N
# de_PREP|+
# este_PROADJ
# segmento_N
# de_PREP|+
# a_ART
# agricultura_N
# ._.
# Em_PREP|+
# as_ART
# duas_NUM
# últimas_ADJ
# décadas_N
# imensas_ADJ
# novas_ADJ
# áreas_N
# de_PREP
# pastagens_N
# foram_VAUX
# incorporadas_PCP
# a_PREP|+
# a_ART
# pecuária_N
# de_PREP|+
# o_ART
# país_N
# com_PREP
# a_ART
# expansão_N
# de_PREP|+
# as_ART
# fronteiras_N
# agrícolas_ADJ
# em_PREP|+
# o_ART
# Brasil_NPROP
# Central_NPROP
# ._.
# E_KC
# a_ART
# ocupação_N
# de_PREP|+
# o_ART
# Cerrado_NPROP
# foi_VAUX
# centrada_PCP
# em_PREP|+
# a_ART
# comercialização_N
# de_PREP
# uma_ART
# forrageira_N
# em_PREP
# especial_ADJ
# ._.
# A_ART
# decubens_ADJ
# ._.
# O_ART
# capim_N
# mais_ADV
# em_PREP|+
# o_ART
# país_N
# invadiu_V
# também_PDEN
# pastagens_N
# antes_ADV
# ocupadas_PCP
# com_PREP
# forrageiras_N
# nativas_ADJ
# como_PREP
# o_ART
# colonião_N
# ,_,
# o_ART
# jaraguá_N
# e_KC
# o_ART
# gordura_ADJ
# em_PREP
# Estados_N
# de_PREP|+
# o_ART
# centro-sul_NPROP
# como_PREP
# São_NPROP
# Paulo_NPROP
# ,_,
# Minas_NPROP
# e_KC
# Paraná_NPROP
# ._.
# Esses_PROADJ
# capins_N
# que_PRO-KS-REL
# exigem_V
# solos_N
# mais_ADV
# férteis_ADJ
# sustentaram_V
# a_ART
# pecuária_N
# brasileira_ADJ
# em_PREP|+
# os_ART
# últimos_ADJ
# 500_NUM
# anos_N
# (_(
# chegaram_V
# em_PREP|+
# os_ART
# navios_N
# negreiros_ADJ
# juntos_ADJ
# com_PREP
# os_ART
# escravos_N
# )_)
# ,_,
# mas_KC
# cederam_V
# lugar_N
# a_PREP
# um_ART
# capim_N
# rústico_ADJ
# ,_,
# produtivo_ADJ
# e_KC
# que_PRO-KS-REL
# se_PROPESS
# adapta_V
# bem_ADV
# também_PDEN
# em_PREP
# solos_N
# menos_ADV
# ._.
# A_ART
# braquiária_N
# decunbens_ADJ
# só_PDEN
# fracassou_V
# em_PREP|+
# a_ART
# Amazônia_NPROP
# e_KC
# é_V
# claro_ADJ
# não_ADV
# podia_VAUX
# se_PROPESS
# dar_V
# bem_ADV
# em_PREP|+
# o_ART
# sul_NPROP
# ._.
# Em_PREP|+
# os_ART
# últimos_ADJ
# anos_N
# a_PREP
# decubens_N
# vem_VAUX
# enfrentando_V
# a_ART
# concorrência_N
# de_PREP
# uma_ART
# outra_PROADJ
# braquiara_N
# (_(
# a_ART
# brizanhta_N
# ou_KC
# braquiarão_N
# )_)
# ._.
# Em_PREP|+
# esse_PROADJ
# caso_N
# porque_KC
# essa_PROADJ
# segunda_ADJ
# variedade_N
# agora_ADV
# também_PDEN
# muito_ADV
# popular_ADJ
# ,_,
# não_ADV
# carrega_V
# os_ART
# problemas_N
# de_PREP|+
# a_ART
# decubens_N
# (_(
# pode_VAUX
# provocar_V
# intoxicação_N
# em_PREP
# animais_N
# jovens_ADJ
# e_KC
# é_V
# muito_ADV
# sujeita_ADJ
# a_PREP|+
# o_ART
# ataque_N
# de_PREP
# pragas_N
# em_PREP
# especial_ADJ
# de_PREP|+
# a_ART
# cigarrinha_N
# )_)
# ._.
# Esse_PROADJ
# grande_ADJ
# sucesso_N
# comercial_ADJ
# não_ADV
# deixou_VAUX
# de_PREP
# carregar_V
# também_PDEN
# alguns_PROADJ
# problemas_N
# ._.
# É_V
# que_KS
# a_ART
# velocidade_N
# de_PREP|+
# a_ART
# ocupação_N
# de_PREP|+
# o_ART
# Cerrado_NPROP
# ,_,
# feito_PCP
# de_PREP
# maneira_N
# desordenada_PCP
# ,_,
# veio_V
# a_ART
# degradação_N
# de_PREP|+
# as_ART
# pastagens_N
# e_KC
# a_ART
# erosão_N
# ._.
# Só_PDEN
# em_PREP
# Mato_NPROP
# Grosso_NPROP
# do_NPROP
# Sul_NPROP
# ,_,
# ,_,
# mais_PREP
# de_PREP
# 50_NUM
# %_N
# de_PREP|+
# as_ART
# pastagens_N
# apresentam_V
# problemas_N
# de_PREP
# degradação_N
# ou_KC
# erosão_N
# ,_,
# o_PRO-KS
# que_PRO-KS
# já_ADV
# está_VAUX
# alarmando_V
# os_ART
# pecuaristas_N
# ._.
# Assim_KS
# os_ART
# desafios_N
# de_PREP|+
# as_ART
# pesquisas_N
# em_PREP|+
# os_ART
# próximos_ADJ
# anos_N
# carrega_V
# a_ART
# necessidade_N
# de_PREP
# um_ART
# novo_ADJ
# modelo_N
# de_PREP
# manejo_N
# e_KC
# ocupação_N
# de_PREP|+
# o_ART
# solo_N
# ._.
# Não_ADV
# só_PDEN
# novas_ADJ
# variedades_N
# melhores_ADJ
# e_KC
# mais_ADV
# resistentes_ADJ
# no_PREP|+
# caso_PREP|+
# de_PREP|+
# as_ART
# sementes_N
# mas_KC
# principalmente_ADV
# novas_ADJ
# formas_N
# de_PREP
# manejo_N
# de_PREP|+
# as_ART
# pastagens_N
# e_KC
# de_PREP
# cultivo_N
# ._.
# Estudo_N
# feito_PCP
# por_PREP
# pesquisadores_N
# de_PREP|+
# a_ART
# Universidade_NPROP
# Federal_NPROP
# do_NPROP
# Piauí_NPROP
# revela_V
# que_KS
# 15,7_NUM
# milhões_N
# de_PREP
# pessoas_N
# são_VAUX
# afetadas_PCP
# por_PREP|+
# a_ART
# desertificação_N
# que_PRO-KS-REL
# ocorre_V
# em_PREP|+
# o_ART
# Nordeste_NPROP
# ._.
# 1,3_NUM
# milhão_N
# de_PREP
# pessoas_N
# vivem_V
# em_PREP
# regiões_N
# onde_ADV-KS-REL
# o_ART
# processo_N
# de_PREP
# degradação_N
# de_PREP|+
# o_ART
# solo_N
# considerado_PCP
# muito_ADV
# grave_ADJ
# e_KC
# a_ART
# terra_N
# tornou_V|+
# se_PROPESS
# praticamente_ADV
# improdutiva_ADJ
# ._.
# A_ART
# área_N
# degradada_PCP
# ,_,
# segundo_PREP
# o_ART
# diagnóstico_N
# ,_,
# é_V
# de_PREP
# 660_NUM
# mil_NUM
# quilômetros_N
# quadrados_ADJ
# ._.
# Isto_PROSUB
# significa_V
# mais_ADV
# os_ART
# territórios_N
# de_PREP|+
# a_ART
# Alemanha_NPROP
# e_KC
# de_PREP|+
# a_ART
# Itália_NPROP
# ,_,
# juntos_ADJ
# ._.
# O_ART
# estudo_N
# é_VAUX
# assinado_PCP
# por_PREP|+
# o_ART
# ,_,
# centro_N
# ligado_PCP
# a_PREP|+
# a_ART
# universidade_N
# que_PRO-KS-REL
# reúne_V
# sociólogos_N
# ,_,
# economistas_N
# ,_,
# biólogos_N
# e_KC
# geógrafos_N
# ._.
# "_"
# Os_ART
# modelos_N
# de_PREP
# desenvolvimento_N
# de_PREP|+
# o_ART
# Nordeste_NPROP
# são_V
# a_ART
# grande_ADJ
# causa_N
# de_PREP|+
# este_PROADJ
# quadro_N
# "_"
# ,_,
# diz_V
# Valdemar_NPROP
# Rodrigues_NPROP
# ,_,
# coordenador_N
# de_PREP|+
# o_ART
# ._.
# Rodrigues_NPROP
# ,_,
# que_PRO-KS-REL
# também_PDEN
# é_V
# secretário_N
# de_PREP|+
# o_ART
# Meio_N
# Ambiente_N
# de_PREP
# Teresina_NPROP
# (_(
# PI_NPROP
# )_)
# ,_,
# fez_V
# doutorado_N
# em_PREP
# desertificação_N
# em_PREP|+
# a_ART
# Cidade_NPROP
# do_NPROP
# México_NPROP
# ._.
# Para_PREP
# chegar_V
# a_PREP
# estes_PROADJ
# números_N
# ,_,
# o_ART
# Núcleo_NPROP
# desenvolveu_V
# uma_ART
# metodologia_N
# com_PREP
# 19_NUM
# variáveis_N
# e_KC
# cruzou_V
# dados_N
# físicos_ADJ
# e_KC
# socioeconômicos_ADJ
# ._.
# Analisou_V
# ,_,
# ,_,
# a_ART
# densidade_N
# populacional_ADJ
# ,_,
# as_ART
# formas_N
# de_PREP
# uso_N
# de_PREP|+
# o_ART
# solo_N
# ,_,
# a_ART
# utilização_N
# de_PREP
# herbicidas_N
# ou_KC
# os_ART
# índices_N
# de_PREP
# salinização_N
# ._.
# Através_PREP|+
# de_PREP|+
# uma_ART
# projeção_N
# ,_,
# feita_PCP
# com_PREP
# cálculos_N
# de_PREP|+
# o_ART
# Programa_NPROP
# das_NPROP
# Nações_NPROP
# Unidas_NPROP
# para_NPROP
# o_NPROP
# Meio_NPROP
# Ambiente_NPROP
# (_(
# PNUMA_NPROP
# )_)
# ,_,
# ele_PROPESS
# estima_V
# em_PREP
# US$_CUR
# 466_NUM
# milhões_N
# por_PREP
# ano_N
# a_ART
# perda_N
# provocada_PCP
# por_PREP|+
# o_ART
# processo_N
# de_PREP
# desertificação_N
# em_PREP|+
# o_ART
# Ne_NPROP
# ._.
# O_ART
# custo_N
# anual_ADJ
# de_PREP
# recuperação_N
# de_PREP|+
# essas_PROADJ
# áreas_N
# seria_V
# de_PREP
# US$_CUR
# 133_NUM
# milhões_N
# ._.
# A_ART
# reversão_N
# de_PREP|+
# o_ART
# processo_N
# depende_V
# de_PREP
# esforços_N
# em_PREP
# várias_PROADJ
# pontas_N
# ,_,
# dizem_V
# os_ART
# técnicos_N
# ._.
# É_V
# divulgar_V
# procedimentos_N
# adequados_PCP
# de_PREP
# manejo_N
# de_PREP|+
# o_ART
# solo_N
# ,_,
# dar_V
# assistência_N
# técnica_ADJ
# eficaz_ADJ
# a_PREP|+
# o_ART
# produtor_N
# e_KC
# implantar_V
# programas_N
# de_PREP
# educação_N
# ambiental_ADJ
# em_PREP|+
# as_ART
# escolas_N
# ._.
# A_ART
# irrigação_N
# inadequada_ADJ
# tornou_V
# estéreis_ADJ
# 30_NUM
# %_N
# de_PREP|+
# as_ART
# áreas_N
# irrigadas_PCP
# em_PREP|+
# o_ART
# Nordeste_NPROP
# ,_,
# diz_V
# Rodrigues_NPROP
# ._.
# Joga_V|+
# se_PROPESS
# muita_PROADJ
# água_N
# em_PREP
# solos_N
# com_PREP
# baixa_ADJ
# capacidade_N
# de_PREP
# absorção_N
# e_KC
# não_ADV
# se_PROPESS
# estudam_V
# obras_N
# de_PREP
# drenagem_N
# ._.
# A_ART
# pecuária_N
# extensiva_ADJ
# ,_,
# praticada_PCP
# em_PREP|+
# a_ART
# região_N
# ,_,
# também_PDEN
# teria_V
# sua_PROADJ
# parcela_N
# de_PREP
# responsabilidade_N
# ._.
# Seriam_V
# necessários_ADJ
# 20_NUM
# ha_N
# ,_,
# em_PREP|+
# o_ART
# semi-árido_N
# nordestino_ADJ
# ,_,
# para_PREP
# alimentar_V
# um_ART
# boi_N
# ._.
# Mas_KC
# ,_,
# em_PREP|+
# a_ART
# prática_N
# ,_,
# costuma_VAUX|+
# se_PROPESS
# colocar_V
# sete_NUM
# animais_N
# por_PREP
# ._.
# Os_ART
# animais_N
# acabam_VAUX
# comendo_V
# as_ART
# plantas_N
# antes_KS
# que_KS
# elas_PROPESS
# produzam_V
# sementes_N
# ,_,
# o_PRO-KS
# que_PRO-KS
# elimina_V
# as_ART
# espécies_N
# melhores_ADJ
# ,_,
# empobrece_V
# a_ART
# terra_N
# e_KC
# torna_V
# a_ART
# cobertura_N
# vegetal_ADJ
# escassa_ADJ
# ._.
# O_ART
# pisoteio_N
# de_PREP|+
# os_ART
# animais_N
# compacta_V
# o_ART
# solo_N
# e_KC
# acelera_V
# a_ART
# degradação_N
# ._.
# Fernando_NPROP
# Barreto_NPROP
# Rodrigues_NPROP
# ,_,
# de_PREP|+
# o_ART
# Centro_NPROP
# Nacional_NPROP
# de_NPROP
# Pesquisa_NPROP
# de_NPROP
# Solos_NPROP
# da_NPROP
# Embrapa_NPROP
# (_(
# Empresa_NPROP
# Brasileira_NPROP
# de_NPROP
# Pesquisa_NPROP
# Agropecuária_NPROP
# )_)
# ,_,
# discorda_V
# de_PREP|+
# os_ART
# dados_N
# de_PREP|+
# o_ART
# Núcleo_NPROP
# ._.
# "_"
# Em_PREP|+
# o_ART
# Nordeste_NPROP
# ,_,
# o_PRO-KS
# que_PRO-KS
# há_V
# ,_,
# são_V
# áreas_N
# com_PREP
# ecossistemas_N
# frágeis_ADJ
# que_PRO-KS-REL
# se_PROPESS
# tornarão_V
# desérticos_ADJ
# se_KS
# não_ADV
# tiverem_V
# manejo_N
# adequado_PCP
# "_"
# ,_,
# diz_V
# ._.
# Ele_PROPESS
# concorda_V
# ,_,
# no_KC
# entanto_KC
# ,_,
# com_PREP
# os_ART
# efeitos_N
# danosos_ADJ
# que_PRO-KS-REL
# a_ART
# irrigação_N
# inadequada_ADJ
# pode_VAUX
# ter_V
# em_PREP|+
# a_ART
# região_N
# ,_,
# salinizando_V
# os_ART
# solos_N
# ._.
# O_ART
# tratamento_N
# existe_V
# ,_,
# mas_KC
# é_V
# caro_ADJ
# ._.
# Pode_VAUX
# ser_VAUX
# feito_PCP
# a_PREP|+
# partir_PREP|+
# de_PREP|+
# a_ART
# aplicação_N
# de_PREP
# uma_ART
# solução_N
# com_PREP
# sulfato_N
# de_PREP
# cálcio_N
# ._.
# "_"
# O_ART
# processo_N
# de_PREP
# desertificação_N
# vem_VAUX
# crescendo_V
# em_PREP|+
# o_ART
# Nordeste_NPROP
# "_"
# ,_,
# diz_V
# Paulo_NPROP
# Roberto_NPROP
# França_NPROP
# ,_,
# de_PREP|+
# a_ART
# Divisão_NPROP
# de_NPROP
# Meio_NPROP
# Ambiente_NPROP
# do_NPROP
# Ministério_NPROP
# das_NPROP
# Relações_NPROP
# Exteriores_NPROP
# ._.
# "_"
# Embora_KS
# sem_PREP
# dados_N
# que_PRO-KS-REL
# revelem_V
# este_PROADJ
# crescimento_N
# ,_,
# as_ART
# práticas_N
# de_PREP
# uso_N
# de_PREP|+
# o_ART
# solo_N
# não_ADV
# mudaram_V
# ._.
# As_ART
# populações_N
# empregam_V
# técnicas_N
# inadequadas_ADJ
# e_KC
# degradam_V
# regiões_N
# ,_,
# migram_V
# para_PREP
# outras_PROSUB
# e_KC
# reempregam_V
# as_ART
# técnicas_N
# ._.
# É_V
# um_ART
# ciclo_N
# contínuo_ADJ
# "_"
# ,_,
# diz_V
# ._.
# Os_ART
# dados_N
# de_PREP
# desertificação_N
# em_PREP|+
# o_ART
# mundo_N
# também_PDEN
# são_V
# assustadores_ADJ
# ._.
# 70_NUM
# %_N
# de_PREP|+
# as_ART
# terras_N
# secas_PCP
# são_VAUX
# afetadas_PCP
# por_PREP|+
# a_ART
# desertificação_N
# ,_,
# o_PRO-KS
# que_PRO-KS
# significa_V
# 3,6_NUM
# bilhões_N
# de_PREP
# ha_N
# ._.
# O_ART
# fenômeno_N
# afeta_V
# a_ART
# vida_N
# de_PREP
# um_NUM
# sexto_N
# de_PREP|+
# a_ART
# população_N
# mundial_ADJ
# ._.
# Durante_PREP
# a_ART
# eco-92_NPROP
# (_(
# conferência_N
# sobre_PREP
# meio_N
# ambiente_N
# que_PRO-KS-REL
# a_ART
# ONU_NPROP
# realizou_V
# em_PREP|+
# o_ART
# Rio_NPROP
# )_)
# ,_,
# acertou_V|+
# se_PROPESS
# que_KS
# os_ART
# países_N
# fariam_V
# uma_ART
# convenção_N
# internacional_ADJ
# sobre_PREP
# desertificação_N
# (_(
# veja_V
# texto_N
# a_PREP|+
# o_ART
# lado_N
# )_)
# ._.
# Um_PROSUB
# de_PREP|+
# os_ART
# nós_N
# de_PREP|+
# o_ART
# acordo_N
# é_V
# a_ART
# discussão_N
# em_PREP
# torno_PREP
# de_PREP
# recursos_N
# financeiros_ADJ
# ._.
# Os_ART
# países_N
# pobres_ADJ
# querem_V
# novos_ADJ
# financiamentos_N
# para_PREP
# enfrentarem_V
# a_ART
# degradação_N
# de_PREP
# suas_PROADJ
# terras_N
# ._.
# Os_ART
# países_N
# ricos_ADJ
# não_ADV
# concordam_V
# ._.
# Seca_N
# ,_,
# desertização_N
# e_KC
# desertificação_N
# são_V
# fenômenos_N
# distintos_ADJ
# e_KC
# que_PRO-KS-REL
# se_PROPESS
# confundem_V
# ._.
# A_ART
# diferença_N
# entre_PREP
# eles_PROPESS
# ,_,
# um_ART
# jogo_N
# de_PREP
# palavras_N
# ,_,
# poderá_VAUX
# ser_V
# determinante_ADJ
# em_PREP|+
# a_ART
# definição_N
# de_PREP
# quais_PRO-KS
# países_N
# receberão_V
# recursos_N
# internacionais_ADJ
# ._.
# Uma_ART
# convenção_N
# internacional_ADJ
# sobre_PREP
# desertificação_N
# está_VAUX
# sendo_VAUX
# discutida_PCP
# por_PREP
# mais_PREP
# de_PREP
# 170_NUM
# países_N
# ._.
# Ela_PROPESS
# aborda_V
# novas_ADJ
# linhas_N
# de_PREP
# financiamento_N
# para_PREP
# áreas_N
# desertificadas_PCP
# ._.
# O_ART
# acordo_N
# pode_VAUX
# ser_VAUX
# fechado_PCP
# em_PREP
# junho_N
# ._.
# Desertificação_N
# é_V
# um_ART
# processo_N
# de_PREP
# degradação_N
# de_PREP|+
# a_ART
# capacidade_N
# produtiva_ADJ
# de_PREP|+
# as_ART
# regiões_N
# secas_PCP
# por_PREP|+
# a_ART
# ação_N
# de_PREP|+
# o_ART
# homem_N
# ._.
# Uma_ART
# zona_N
# desertificada_PCP
# deixa_V
# de_PREP
# ser_V
# produtiva_ADJ
# ._.
# A_ART
# recuperação_N
# é_V
# possível_ADJ
# ,_,
# mas_KC
# o_ART
# custo_N
# pode_VAUX
# ser_V
# proibitivo_ADJ
# ._.
# A_ART
# definição_N
# internacional_ADJ
# de_PREP
# desertificação_N
# baseia_V|+
# se_PROPESS
# em_PREP|+
# o_ART
# resultado_N
# de_PREP
# uma_ART
# equação_N
# que_PRO-KS-REL
# revela_V
# o_ART
# índice_N
# de_PREP
# aridez_N
# de_PREP
# uma_ART
# região_N
# ._.
# Divide_V|+
# se_PROPESS
# a_ART
# evaporação_N
# por_PREP|+
# a_ART
# precipitação_N
# ._.
# Se_KS
# o_ART
# índice_N
# estiver_V
# entre_PREP
# 0,05_NUM
# e_KC
# 0,65_NUM
# pode_VAUX
# tratar_V|+
# se_PROPESS
# de_PREP
# uma_ART
# região_N
# desertificada_PCP
# ._.
# Somente_PDEN
# o_ART
# Nordeste_NPROP
# ,_,
# em_PREP|+
# o_ART
# Brasil_NPROP
# ,_,
# enquadra_V|+
# se_PROPESS
# em_PREP|+
# esta_PROADJ
# definição_N
# ._.
# A_ART
# região_N
# de_PREP
# Alegrete_NPROP
# (_(
# RS_NPROP
# )_)
# tem_V
# índice_N
# de_PREP
# aridez_N
# superior_ADJ
# a_ART
# ._.
# Em_PREP|+
# a_ART
# prática_N
# ,_,
# ela_PROPESS
# não_ADV
# será_VAUX
# atingida_PCP
# por_PREP|+
# definir_V
# a_ART
# convenção_N
# ._.
# Desertização_N
# é_V
# o_ART
# processo_N
# de_PREP
# formação_N
# de_PREP
# desertos_N
# ._.
# É_V
# um_ART
# fenômeno_N
# natural_ADJ
# ._.
# secas_ADJ
# são_V
# áreas_N
# onde_ADV-KS-REL
# o_PRO-KS
# que_PRO-KS
# se_PROPESS
# perde_V
# de_PREP
# água_N
# por_PREP|+
# a_ART
# evaporação_N
# é_V
# o_PRO-KS
# que_PRO-KS
# se_PROPESS
# ganha_V
# por_PREP|+
# a_ART
# chuva_N
# ._.
# É_V
# um_ART
# fenômeno_N
# climático_ADJ
# natural_ADJ
# ._.
# A_ART
# desertificação_N
# só_PDEN
# ocorre_V
# em_PREP
# regiões_N
# de_PREP
# seca_N
# ._.
# O_ART
# governo_N
# paulista_ADJ
# vai_VAUX
# investir_V
# US$_CUR
# 6,7_NUM
# milhões_N
# esse_PROADJ
# ano_N
# em_PREP|+
# o_ART
# combate_N
# a_PREP|+
# a_ART
# erosão_N
# ._.
# A_ART
# verba_N
# ,_,
# aprovada_PCP
# em_PREP|+
# o_ART
# orçamento_N
# de_PREP
# o_ART
# estado_N
# ,_,
# é_V
# para_PREP
# fazer_V
# o_ART
# mapeamento_N
# de_PREP
# cerca_PREP
# de_PREP
# 40_NUM
# %_N
# de_PREP|+
# o_ART
# solo_N
# paulista_ADJ
# ._.
# O_ART
# mapa_N
# vai_VAUX
# classificar_V
# os_ART
# diferentes_ADJ
# tipos_N
# de_PREP
# solo_N
# e_KC
# determinar_V
# quais_PRO-KS
# as_ART
# atividades_N
# agrícolas_ADJ
# são_VAUX
# recomendadas_PCP
# para_PREP
# cada_PROADJ
# região_N
# ._.
# Evita_V
# ,_,
# de_PREP|+
# essa_PROADJ
# forma_N
# ,_,
# que_KS
# plantios_N
# inadequados_ADJ
# a_PREP|+
# o_ART
# tipo_N
# de_PREP
# solo_N
# acelerem_V
# o_ART
# processo_N
# de_PREP
# erosão_N
# ._.
# São_NPROP
# Paulo_NPROP
# perde_V
# por_PREP
# ano_N
# 190_NUM
# milhões_N
# de_PREP
# toneladas_N
# de_PREP
# terra_N
# com_PREP
# a_ART
# erosão_N
# ,_,
# um_ART
# prejuízo_N
# equivalente_ADJ
# a_PREP
# US$_CUR
# 200_NUM
# milhões_N
# ._.
# "_"
# Uma_PROSUB
# de_PREP|+
# as_ART
# principais_ADJ
# causas_N
# de_PREP|+
# a_ART
# erosão_N
# é_V
# o_ART
# uso_N
# inadequado_ADJ
# de_PREP|+
# o_ART
# solo_N
# "_"
# ,_,
# diz_V
# Guido_NPROP
# José_NPROP
# da_NPROP
# Costa_NPROP
# ,_,
# presidente_N
# de_PREP|+
# a_ART
# Associação_NPROP
# dos_NPROP
# Engenheiros_NPROP
# Agrônomos_NPROP
# do_NPROP
# Estado_NPROP
# ._.
# O_ART
# café_N
# ,_,
# exemplifica_V
# Costa_NPROP
# ,_,
# não_ADV
# deveria_VAUX
# ser_VAUX
# plantado_PCP
# em_PREP|+
# o_ART
# Vale_NPROP
# do_NPROP
# Paraíba_NPROP
# ._.
# "_"
# O_ART
# solo_N
# de_PREP|+
# a_ART
# região_N
# é_V
# bom_ADJ
# para_PREP
# pastagens_N
# ,_,
# hortaliças_N
# e_KC
# frutas_N
# "_"
# ,_,
# diz_V
# ._.
# Atualmente_ADV
# entre_PREP
# 10_NUM
# %_N
# e_KC
# 15_NUM
# %_N
# de_PREP|+
# a_ART
# área_N
# de_PREP|+
# o_ART
# Estado_N
# mapeada_PCP
# em_PREP
# escala_N
# 1:100.000_N|AP
# (_(
# 1_NUM
# centímetro_N
# quadrado_ADJ
# de_PREP
# mapa_N
# corresponde_V
# a_PREP
# 100_NUM
# hectares_N
# )_)
# ._.
# A_ART
# escala_N
# ,_,
# diz_V
# Costa_NPROP
# ,_,
# é_V
# a_ART
# ideal_N
# para_PREP
# precisar_V
# quais_PRO-KS
# culturas_N
# se_PROPESS
# adequam_V
# a_PREP|+
# o_ART
# solo_N
# ._.
# O_ART
# trabalho_N
# ,_,
# previsto_V
# para_PREP
# durar_V
# cinco_NUM
# anos_N
# ,_,
# vai_VAUX
# começar_V
# ,_,
# em_PREP
# maio_N
# próximo_ADJ
# ,_,
# por_PREP|+
# a_ART
# Oeste_NPROP
# ._.
# O_ART
# local_N
# foi_VAUX
# escolhido_PCP
# por_PREP
# ter_V
# poucas_PROADJ
# pesquisas_N
# em_PREP|+
# a_ART
# área_N
# de_PREP
# solo_N
# e_KC
# por_PREP
# ser_VAUX
# considerada_PCP
# uma_ART
# região_N
# com_PREP
# potencial_N
# de_PREP
# erosão_N
# ,_,
# explica_V
# Hélio_NPROP
# do_NPROP
# Prado_NPROP
# ,_,
# coordenador_N
# de_PREP
# Levantamento_N
# do_N
# Solo_N
# de_PREP|+
# o_ART
# Instituto_NPROP
# Agronômico_NPROP
# de_NPROP
# Campinas_NPROP
# ,_,
# um_PROSUB
# de_PREP|+
# os_ART
# responsáveis_N
# por_PREP|+
# o_ART
# mapeamento_N
# ._.
# Segundo_PREP
# Prado_NPROP
# ,_,
# a_ART
# área_N
# inicial_ADJ
# é_V
# formada_PCP
# por_PREP|+
# o_ART
# Pontal_NPROP
# de_NPROP
# Paranapanema_NPROP
# até_PREP
# Marília_NPROP
# ,_,
# passando_V
# por_PREP
# Barretos_NPROP
# e_KC
# por_PREP|+
# a_ART
# divisa_N
# de_PREP
# Minas_NPROP
# ._.
# Devem_VAUX
# ficar_VAUX
# faltando_V
# em_PREP|+
# o_ART
# trabalho_N
# as_ART
# regiões_N
# a_PREP|+
# o_ART
# norte_N
# de_PREP|+
# o_ART
# Ribeirão_NPROP
# Preto_NPROP
# e_KC
# Vale_NPROP
# do_NPROP
# Paraíba_NPROP
# ._.
# "_"
# Não_ADV
# há_V
# técnicos_N
# suficientes_ADJ
# "_"
# ,_,
# diz_V
# Prado_NPROP
# ._.
# Quando_KS
# pronto_ADJ
# ,_,
# o_ART
# mapa_N
# terá_V
# uma_ART
# definição_N
# de_PREP
# classe_N
# de_PREP
# uso_N
# ,_,
# com_PREP
# variação_N
# de_PREP
# a_PREP
# ._.
# O_ART
# solo_N
# 1_N|AP
# é_V
# uma_ART
# terra_N
# rica_ADJ
# em_PREP
# nutrientes_N
# (_(
# fértil_ADJ
# )_)
# ,_,
# com_PREP
# relevo_N
# plano_ADJ
# e_KC
# pouca_PROADJ
# erosão_N
# ._.
# Um_ART
# exemplo_N
# é_V
# a_ART
# região_N
# de_PREP
# Ribeirão_NPROP
# Preto_NPROP
# ._.
# O_ART
# solo_N
# 8_N|AP
# são_V
# as_ART
# resersas_N
# naturais_ADJ
# ._.
# O_ART
# solo_N
# 3_N|AP
# é_V
# apresenta_V
# boa_ADJ
# quantidade_N
# de_PREP
# nutriente_N
# mas_KC
# ,_,
# devido_PREP|+
# a_PREP|+
# o_ART
# relevo_N
# ondulado_PCP
# ,_,
# sujeito_PCP
# a_PREP|+
# a_ART
# erosão_N
# ._.
# O_ART
# trabalho_N
# será_VAUX
# feito_PCP
# por_PREP|+
# o_ART
# Instituto_NPROP
# Agronômico_NPROP
# ,_,
# por_PREP
# técnicos_N
# de_PREP|+
# a_ART
# Escola_NPROP
# Superior_NPROP
# de_NPROP
# Agricultura_NPROP
# Luiz_NPROP
# de_NPROP
# Queiroz_NPROP
# (_(
# Esalq_NPROP
# )_)
# e_KC
# por_PREP|+
# a_ART
# ._.
# O_ART
# plano_N
# inicial_ADJ
# ,_,
# diz_V
# Costa_NPROP
# ,_,
# é_V
# uma_ART
# equipe_N
# de_PREP
# dez_NUM
# técnicos_N
# de_PREP|+
# o_ART
# Instituto_NPROP
# Agronômico_NPROP
# e_KC
# outros_PROADJ
# oito_N
# de_PREP|+
# a_ART
# Esalq_NPROP
# ._.
# Para_PREP
# isso_PROSUB
# ,_,
# cada_PROADJ
# técnico_N
# deverá_VAUX
# ser_V
# responsável_ADJ
# por_PREP
# três_NUM
# quadrícolas_N
# -_-
# área_N
# delimitada_PCP
# em_PREP
# 280_NUM
# mil_NUM
# ha_N
# ._.
# Após_PREP
# o_ART
# mapa_N
# ,_,
# será_VAUX
# feito_PCP
# um_ART
# relatório_N
# técnico_ADJ
# ,_,
# que_PRO-KS-REL
# vai_VAUX
# apontar_V
# as_ART
# características_N
# de_PREP|+
# o_ART
# solo_N
# ._.
# O_ART
# Estado_N
# de_PREP
# São_NPROP
# Paulo_NPROP
# perde_V
# ,_,
# com_PREP
# a_ART
# erosão_N
# ,_,
# entre_PREP
# 10_NUM
# e_KC
# 13_NUM
# bilhões_N
# de_PREP
# m3_N
# de_PREP
# água_N
# por_PREP
# ano_N
# ._.
# Essa_PROADJ
# quantidade_N
# é_V
# suficiente_ADJ
# para_PREP
# encher_V
# um_ART
# lago_N
# de_PREP
# 130_NUM
# quilômetros_N
# ,_,
# com_PREP
# cinco_NUM
# quilômetros_N
# de_PREP
# largura_N
# e_KC
# 20_NUM
# metros_N
# de_PREP
# profundidade_N
# ._.
# "_"
# O_ART
# número_N
# é_V
# mais_ADV
# alarmante_ADJ
# se_KS
# pensarmos_V
# que_KS
# daria_V
# para_PREP
# abastecer_V
# toda_PROADJ
# a_ART
# população_N
# brasileira_ADJ
# por_PREP
# oito_NUM
# meses_N
# "_"
# ,_,
# diz_V
# Dalmo_NPROP
# Rosalen_NPROP
# ,_,
# de_PREP|+
# a_ART
# ._.
# Há_V
# cidades_N
# que_PRO-KS-REL
# enfrentam_V
# programas_N
# de_PREP
# racionamento_N
# de_PREP
# água_N
# ._.
# Um_ART
# exemplo_N
# é_V
# a_ART
# bacia_N
# de_PREP|+
# o_ART
# Vale_NPROP
# do_NPROP
# Piracicaba_NPROP
# (_(
# a_PREP
# 170_NUM
# quilômetros_N
# a_PREP
# noroeste_N
# de_PREP
# São_NPROP
# Paulo_NPROP
# )_)
# ._.
# Grande_ADJ
# parte_N
# de_PREP|+
# esse_PROADJ
# volume_N
# de_PREP
# água_N
# ,_,
# que_PRO-KS-REL
# provém_V
# de_PREP|+
# as_ART
# chuvas_N
# ,_,
# poderia_VAUX
# ser_VAUX
# absorvida_PCP
# por_PREP|+
# o_ART
# solo_N
# e_KC
# chegar_V
# a_PREP|+
# o_ART
# lençol_N
# freático_ADJ
# -_-
# a_ART
# corrente_N
# de_PREP
# água_N
# subterrânea_ADJ
# que_PRO-KS-REL
# fica_V
# a_ART
# pouca_PROADJ
# profundidade_N
# de_PREP|+
# o_ART
# solo_N
# ._.
# De_PREP|+
# essa_PROADJ
# forma_N
# ,_,
# diz_V
# Rosalen_NPROP
# ,_,
# melhorariam_V
# as_ART
# condições_N
# de_PREP
# produção_N
# de_PREP|+
# o_ART
# solo_N
# e_KC
# de_PREP|+
# as_ART
# nascentes_N
# de_PREP|+
# os_ART
# rios_N
# ._.
# "_"
# Não_ADV
# haveria_V
# seca_N
# em_PREP|+
# as_ART
# nascentes_N
# em_PREP|+
# o_ART
# inverno_N
# "_"
# ,_,
# diz_V
# Rosalen_NPROP
# ._.
# Sem_PREP
# controle_N
# de_PREP|+
# o_ART
# escoamento_N
# ,_,
# a_ART
# água_N
# corre_V
# para_PREP
# o_ART
# rio_N
# ,_,
# levando_V
# a_ART
# terra_N
# e_KC
# o_ART
# adubo_N
# ._.
# A_ART
# terra_N
# vai_V
# para_PREP
# o_ART
# fundo_N
# de_PREP|+
# o_ART
# rio_N
# ,_,
# diminuindo_V
# seu_PROADJ
# leito_N
# ._.
# Outro_PROADJ
# problema_N
# é_V
# que_KS
# o_ART
# solo_N
# perde_V
# seus_PROADJ
# nutrientes_N
# ._.
# "_"
# Para_PREP
# formar_V
# o_ART
# solo_N
# ,_,
# leva_V|+
# se_PROPESS
# centenas_N
# de_PREP
# anos_N
# ._.
# E_KC
# ele_PROPESS
# se_PROPESS
# perde_V
# em_PREP
# um_ART
# piscar_V
# de_PREP
# olhos_N
# "_"
# ,_,
# diz_V
# Rosalen_NPROP
# ._.
# A_ART
# erosão_N
# é_V
# a_ART
# "_"
# lavagem_N
# "_"
# de_PREP|+
# a_ART
# camada_N
# mais_ADV
# superficial_ADJ
# de_PREP|+
# o_ART
# solo_N
# por_PREP|+
# a_ART
# ação_N
# de_PREP|+
# a_ART
# chuva_N
# ou_KC
# de_PREP|+
# o_ART
# vento_N
# ._.
# É_V
# como_KS
# se_KS
# um_ART
# grande_ADJ
# balde_N
# d'_PREP
# água_N
# -_-
# em_PREP|+
# o_ART
# caso_N
# a_ART
# chuva-_N
# carregasse_V
# a_ART
# "_"
# sujeira_N
# "para_PREP
# os_ART
# rios_N
# ._.
# O_ART
# problema_N
# é_V
# que_KS
# essa_PROADJ
# camada_N
# de_PREP|+
# a_ART
# superfície_N
# tem_V
# nutrientes_N
# e_KC
# materiais_N
# orgânicos_ADJ
# que_PRO-KS-REL
# tornam_V
# o_ART
# solo_N
# fértil_ADJ
# ._.
# Sem_PREP
# essas_PROADJ
# camadas_N
# ,_,
# o_ART
# solo_N
# vai_VAUX
# ficando_V
# árido_ADJ
# ._.
# São_V
# as_ART
# camadas_N
# superficiais_ADJ
# que_PRO-KS-REL
# sustentam_V
# as_ART
# plantas_N
# em_PREP|+
# o_ART
# chão_N
# "_"
# explica_V
# Guido_NPROP
# José_NPROP
# da_NPROP
# Costa_NPROP
# ,_,
# presidente_N
# de_PREP|+
# a_ART
# Associação_NPROP
# dos_NPROP
# Engenheiros_NPROP
# Agrônomos_NPROP
# do_NPROP
# Estado_NPROP
# de_PREP
# São_NPROP
# Paulo_NPROP
# ._.
# Os_ART
# grandes_ADJ
# buracos_N
# em_PREP|+
# a_ART
# terra_N
# causados_PCP
# por_PREP|+
# a_ART
# erosão_N
# são_VAUX
# chamados_PCP
# de_PREP
# voçorocas_N
# ._.
# Se_KS
# o_ART
# processo_N
# de_PREP
# erosão_N
# não_ADV
# for_VAUX
# evitado_PCP
# pode_VAUX
# levar_V
# a_ART
# desertificação_N
# (_(
# veja_V
# texto_N
# acima_ADV
# )_)
# ._.
# Em_PREP|+
# o_ART
# Rio_NPROP
# Grande_NPROP
# do_NPROP
# Sul_NPROP
# ,_,
# já_ADV
# há_V
# exemplos_N
# de_PREP
# áreas_N
# fortemente_ADV
# degradadas_PCP
# por_PREP|+
# a_ART
# erosão_N
# ,_,
# como_PREP
# o_ART
# "_"
# deserto_NPROP
# dos_NPROP
# pampas_NPROP
# "_"
# ,_,
# em_PREP
# Alegrete_NPROP
# ._.
# A_ART
# melhor_ADJ
# forma_N
# de_PREP
# evitar_V
# a_ART
# erosão_N
# é_V
# manter_V
# a_PREP
# terra_N
# coberta_PCP
# ._.
# "_"
# A_ART
# planta_N
# segura_V
# a_ART
# água_N
# em_PREP|+
# o_ART
# solo_N
# "_"
# ,_,
# explica_V
# Costa_NPROP
# ._.
# Técnicas_N
# como_PREP
# o_ART
# plantio_N
# direto_ADJ
# evitam_V
# a_ART
# erosão_N
# ._.
# Consiste_V
# em_PREP
# plantar_V
# uma_ART
# cultura_N
# em_PREP|+
# cima_PREP|+
# de_PREP|+
# a_ART
# palhada_N
# de_PREP|+
# a_ART
# lavoura_N
# anterior_ADJ
# ._.
# Assim_KS
# ,_,
# a_ART
# terra_N
# fica_V
# sempre_ADV
# coberta_PCP
# e_KC
# protegida_PCP
# contra_PREP
# a_ART
# ação_N
# erosiva_ADJ
# de_PREP|+
# os_ART
# ventos_N
# e_KC
# de_PREP|+
# a_ART
# chuva_N
# ._.
# Um_PROSUB
# de_PREP|+
# os_ART
# problemas_N
# de_PREP|+
# o_ART
# processo_N
# de_PREP
# erosão_N
# é_V
# que_KS
# a_ART
# água_N
# escorre_V
# e_KC
# leva_V
# a_ART
# terra_N
# e_KC
# seus_PROADJ
# nutrientes_N
# para_PREP
# os_ART
# rios_N
# ._.
# Como_KS
# a_ART
# água_N
# não_ADV
# absorvida_PCP
# por_PREP|+
# a_ART
# terra_N
# ,_,
# chega_V
# mais_ADV
# rápido_ADJ
# a_PREP|+
# os_ART
# rios_N
# e_KC
# provoca_V
# enchentes_N
# ._.
# A_ART
# terra_N
# ,_,
# que_PRO-KS-REL
# escoa_V
# junto_ADV
# ,_,
# chega_V
# a_PREP|+
# o_ART
# rio_N
# e_KC
# diminui_V
# o_ART
# seu_PROADJ
# leito_N
# (_(
# assoreamento_N
# )_)
# ._.
# É_V
# outra_PROADJ
# causa_N
# de_PREP
# enchentes_N
# ._.
# Os_ART
# criadores_N
# de_PREP
# limousin_N
# ,_,
# gado_N
# nascido_PCP
# em_PREP|+
# a_ART
# França_NPROP
# e_KC
# usado_PCP
# em_PREP|+
# o_ART
# Brasil_NPROP
# para_PREP
# produção_N
# de_PREP
# carne_N
# ,_,
# promovem_V
# a_ART
# 1ª_ADJ
# Exposição_NPROP
# Nacional_NPROP
# de_PREP|+
# a_ART
# raça_N
# ._.
# O_ART
# evento_N
# começa_V
# hoje_ADV
# e_KC
# vai_V
# até_PREP
# domingo_N
# ._.
# O_ART
# limousin_N
# é_VAUX
# empregado_PCP
# também_PDEN
# em_PREP|+
# o_ART
# cruzamento_N
# industrial_ADJ
# com_PREP
# o_ART
# nelore_N
# e_KC
# outras_PROADJ
# raças_N
# zebuínas_ADJ
# ._.
# A_ART
# experiência_N
# é_VAUX
# feita_PCP
# para_PREP
# melhorar_V
# a_ART
# qualidade_N
# de_PREP|+
# a_ART
# carne_N
# brasileira_ADJ
# ,_,
# a_PREP|+
# partir_PREP|+
# de_PREP|+
# a_ART
# mistura_N
# de_PREP
# sangue_N
# europeu_ADJ
# (_(
# limousin_N
# ,_,
# mais_ADV
# produtivo_ADJ
# )_)
# a_PREP|+
# o_ART
# indiano_ADJ
# zebu_N
# (_(
# mais_ADV
# rústico_ADJ
# )_)
# ._.
# Os_ART
# julgamentos_N
# de_PREP|+
# o_ART
# limousin_N
# serão_VAUX
# realizados_PCP
# hoje_ADV
# ._.
# Também_PDEN
# hoje_ADV
# ,_,
# a_PREP|+
# as_ART
# 20h_N|HOR
# ,_,
# um_ART
# leilão_N
# coloca_V
# em_PREP
# oferta_N
# vacas_N
# prenhas_ADJ
# de_PREP|+
# a_ART
# raça_N
# ._.
# Quarta-feira_N
# ,_,
# a_PREP|+
# as_ART
# 20h_N|HOR
# ,_,
# o_ART
# pregão_N
# deve_VAUX
# vender_V
# 30_NUM
# animais_N
# ,_,
# entre_PREP
# nacionais_ADJ
# e_KC
# importados_PCP
# ._.
# Tem_V
# início_N
# dia_N
# 25_N|AP
# de_PREP|+
# este_PROADJ
# mês_N
# a_ART
# 60ª_ADJ
# Exposição_NPROP
# Nacional_NPROP
# de_NPROP
# Gado_NPROP
# Zebu_NPROP
# (_(
# Expozebu_NPROP
# )_)
# em_PREP
# Uberaba_NPROP
# (_(
# MG_NPROP
# )_)
# ._.
# É_V
# a_ART
# maior_ADJ
# e_KC
# mais_ADV
# tradicional_ADJ
# feira_N
# de_PREP|+
# os_ART
# bovinos_N
# de_PREP
# sangue_N
# zebuíno_ADJ
# ,_,
# que_PRO-KS-REL
# têm_V
# origem_N
# em_PREP|+
# a_ART
# Índia_NPROP
# ._.
# a_PREP
# o_ART
# contrário_N
# a_ART
# Expointer_NPROP
# ,_,
# vitrine_N
# gaúcha_ADJ
# de_PREP|+
# o_ART
# gado_N
# europeu_ADJ
# selecionado_PCP
# em_PREP|+
# o_ART
# Brasil_NPROP
# ,_,
# em_PREP
# Uberaba_NPROP
# predominam_V
# os_ART
# animais_N
# indianos_ADJ
# ,_,
# mais_ADV
# resistentes_ADJ
# a_PREP|+
# o_ART
# calor_N
# de_PREP|+
# os_ART
# trópicos_N
# ,_,
# apesar_PREP
# de_PREP
# menos_ADV
# produtivos_ADJ
# que_KS
# os_PROSUB
# de_PREP|+
# a_ART
# Europa_NPROP
# ._.
# mais_PREP
# de_PREP
# mil_NUM
# cabeças_N
# de_PREP
# nelore_N
# ,_,
# gir_N
# ,_,
# tabapuã_N
# e_KC
# guzerá_N
# ,_,
# as_ART
# mais_ADV
# conhecidas_PCP
# raças_N
# zebuínas_ADJ
# criadas_PCP
# ,_,
# juntam_V|+
# se_PROPESS
# este_PROADJ
# ano_N
# a_PREP|+
# a_ART
# brahma_N
# ,_,
# chegada_PCP
# recentemente_ADV
# de_PREP|+
# os_ART
# EUA_NPROP
# ,_,
# para_PREP
# julgamento_N
# (_(
# avaliação_N
# de_PREP|+
# a_ART
# qualidade_N
# )_)
# e_KC
# leilões_N
# ._.
# Em_PREP
# 93_N
# ,_,
# a_ART
# Associação_NPROP
# Brasileira_NPROP
# dos_NPROP
# Criadores_NPROP
# de_NPROP
# Zebu_NPROP
# (_(
# ABCZ_NPROP
# )_)
# ,_,
# promotora_N
# de_PREP|+
# a_ART
# feira_N
# ,_,
# contabilizou_V
# US$_CUR
# 6_NUM
# milhões_N
# com_PREP
# a_ART
# venda_N
# de_PREP
# animais_N
# ,_,
# valor_N
# que_PRO-KS-REL
# deverá_VAUX
# ser_VAUX
# superado_PCP
# este_PROADJ
# ano_N
# ,_,
# acredita_V
# Rômulo_NPROP
# Camargos_NPROP
# ,_,
# presidente_N
# de_PREP|+
# a_ART
# entidade_N
# ._.
# "_"
# Houve_V
# valorização_N
# em_PREP
# dólar_N
# de_PREP|+
# os_ART
# animais_N
# de_PREP
# elite_N
# de_PREP|+
# as_ART
# raças_N
# zebuínas_ADJ
# "_"
# ,_,
# explica_V
# Camargos_NPROP
# ._.
# Em_PREP|+
# esses_PROADJ
# leilões_N
# são_V
# comuns_ADJ
# a_ART
# quebra_N
# sucessiva_ADJ
# de_PREP
# recordes_N
# médios_ADJ
# de_PREP
# preços_N
# e_KC
# as_ART
# cotações_N
# milionárias_ADJ
# pagas_PCP
# a_PREP
# lotes_N
# individuais_ADJ
# ,_,
# principalmente_ADV
# para_PREP
# os_ART
# nelore_N
# ._.
# Apesar_PREP|+
# de_PREP|+
# a_ART
# inauguração_N
# oficial_ADJ
# estar_VAUX
# marcada_PCP
# para_PREP
# o_ART
# dia_N
# 3_N|AP
# de_PREP
# maio_N
# ,_,
# os_ART
# principais_ADJ
# leilões_N
# e_KC
# julgamentos_N
# acontecem_V
# em_PREP|+
# a_ART
# semana_N
# anterior_ADJ
# ._.
# Dia_N
# 26_N|AP
# de_PREP
# abril_N
# ,_,
# a_ART
# Reserva_NPROP
# Especial_NPROP
# de_NPROP
# Nelore_NPROP
# ,_,
# abre_V
# o_ART
# calendário_N
# de_PREP|+
# os_ART
# pregões_N
# de_PREP
# elite_N
# ;_;
# dia_N
# 27_N|AP
# ,_,
# o_ART
# nelore_N
# e_KC
# o_ART
# tabapuã_N
# começam_V
# a_ART
# fase_N
# de_PREP
# julgamento_N
# ._.
# O_ART
# andaluz_N
# é_VAUX
# conhecido_PCP
# em_PREP|+
# a_ART
# Europa_NPROP
# o_ART
# cavalo_N
# de_PREP|+
# o_ART
# toureiro_N
# ._.
# É_V
# ele_PROPESS
# quem_PRO-KS
# conduz_V
# o_ART
# cavaleiro_N
# em_PREP|+
# o_ART
# embate_N
# com_PREP
# o_ART
# touro_N
# em_PREP|+
# as_ART
# arenas_N
# de_PREP
# Portugal_NPROP
# e_KC
# Espanha_NPROP
# ._.
# originário_ADJ
# de_PREP
# a_ART
# Península_NPROP
# Ibérica_NPROP
# ,_,
# o_ART
# andaluz_N
# bastante_ADV
# usado_PCP
# em_PREP
# esportes_N
# e_KC
# provas_N
# em_PREP|+
# o_ART
# Brasil_NPROP
# ._.
# O_ART
# publicitário_N
# Eduardo_NPROP
# Fischer_NPROP
# preside_V
# a_PREP
# Federação_NPROP
# Brasileira_NPROP
# do_NPROP
# Andaluz_NPROP
# ,_,
# sediada_PCP
# em_PREP
# São_NPROP
# Paulo_NPROP
# ,_,
# com_PREP
# cerca_PREP
# de_PREP
# 180_NUM
# criadores_N
# ._.
# Segundo_PREP
# previsão_N
# de_PREP
# Fischer_NPROP
# ,_,
# o_ART
# quadro_N
# deve_VAUX
# aumentar_V
# para_PREP
# 300_NUM
# criadores_N
# até_PREP
# o_ART
# final_N
# de_PREP|+
# este_PROADJ
# ano_N
# ._.
# O_ART
# andaluz_N
# de_PREP
# sangue_N
# espanhol_ADJ
# ,_,
# mais_ADV
# fino_ADJ
# ,_,
# é_VAUX
# usado_PCP
# em_PREP
# provas_N
# funcionais_ADJ
# ._.
# Já_KC
# o_ART
# lusitano_N
# é_V
# galopador_N
# ,_,
# próprio_PROSUB
# para_PREP
# touradas_N
# ._.
# A_ART
# procura_N
# por_PREP|+
# a_ART
# raça_N
# tem_VAUX
# crescido_PCP
# bastante_ADV
# e_KC
# a_ART
# oferta_N
# acompanhado_PCP
# ._.
# Somente_PDEN
# em_PREP
# 93_N
# ,_,
# foram_VAUX
# realizados_PCP
# quatro_NUM
# leilões_N
# oficiais_ADJ
# ._.
# O_ART
# cavalo_N
# andaluz_ADJ
# (_(
# leia_V
# texto_N
# a_PREP|+
# o_ART
# lado_N
# )_)
# saiu_V
# a_ART|+
# em_PREP
# frente_PREP
# de_PREP
# outras_PROADJ
# raças_N
# equinas_ADJ
# em_PREP
# 94_N
# ._.
# foi_V
# o_ART
# leilão_N
# oficial_ADJ
# em_PREP|+
# o_ART
# início_N
# de_PREP
# março_N
# ._.
# Em_PREP|+
# o_ART
# último_ADJ
# dia_N
# 5_N|AP
# de_PREP
# abril_N
# ,_,
# o_ART
# criador_N
# Enio_NPROP
# Monte_NPROP
# promoveu_V
# um_ART
# remate_N
# exclusivo_ADJ
# de_PREP
# seu_PROADJ
# plantel_N
# ._.
# Monte_NPROP
# vendeu_V
# 29_NUM
# cavalos_N
# por_PREP
# Cr$_CUR
# 208,2_NUM
# milhões_N
# ,_,
# obtendo_V
# cotação_N
# média_ADJ
# de_PREP
# Cr$_CUR
# 7,2_NUM
# milhões_N
# ou_KC
# 7.635_NUM
# URVs_N
# ._.
# A_ART
# oferta_N
# de_PREP
# andaluz_N
# continua_V
# ._.
# Hoje_ADV
# ,_,
# exatamente_ADV
# uma_NUM
# semana_N
# depois_PREP
# de_PREP
# o_ART
# ,_,
# outros_PROADJ
# dois_NUM
# grandes_ADJ
# selecionadores_N
# de_PREP|+
# a_ART
# raça_N
# ,_,
# Toni_NPROP
# Pereira_NPROP
# e_KC
# Paulo_NPROP
# Gavião_NPROP
# Gonzaga_NPROP
# ,_,
# ofertam_V
# 30_NUM
# animais_N
# puro-sangue_ADJ
# em_PREP|+
# o_ART
# leilão_N
# 3º_ADJ
# ,_,
# em_PREP|+
# a_ART
# Sociedade_NPROP
# Hípica_NPROP
# Paulista_NPROP
# ._.
# Enio_NPROP
# Monte_NPROP
# ,_,
# cujo_PRO-KS-REL
# haras_N
# Itapuã_NPROP
# fica_V
# em_PREP|+
# a_ART
# cidade_N
# de_PREP
# Arandu_NPROP
# (_(
# 283_NUM
# km_N
# a_PREP
# oeste_N
# de_PREP
# São_NPROP
# Paulo_NPROP
# )_)
# ,_,
# é_VAUX
# considerado_PCP
# ,_,
# Toni_NPROP
# Pereira_NPROP
# ,_,
# um_PROSUB
# de_PREP|+
# os_ART
# maiores_ADJ
# importadores_N
# de_PREP
# andaluz_N
# de_PREP
# Portugal_NPROP
# e_KC
# de_PREP|+
# a_ART
# Espanha_NPROP
# ._.
# Ele_PROPESS
# considerou_V
# "_"
# satisfatório_ADJ
# "_"
# o_ART
# resultado_N
# de_PREP
# seu_PROADJ
# leilão_N
# ._.
# "_"
# Esteve_V
# dentro_PREP|+
# de_PREP|+
# as_ART
# expectativas_N
# "_"
# ,_,
# disse_V
# ._.
# Monte_NPROP
# ofereceu_V
# duas_NUM
# condições_N
# de_PREP
# pagamento_N
# a_PREP|+
# os_ART
# compradores_N
# de_PREP|+
# os_ART
# cavalos_N
# :_:
# cinco_NUM
# parcelas_N
# mensais_ADJ
# corrigidas_PCP
# por_PREP|+
# a_ART
# URV_NPROP
# ou_KC
# duas_NUM
# parcelas_N
# ,_,
# sendo_V
# uma_PROSUB
# de_PREP
# 50_NUM
# %_N
# em_PREP|+
# o_ART
# ato_N
# de_PREP|+
# a_ART
# compra_N
# e_KC
# os_ART
# 50_NUM
# %_N
# pagos_PCP
# após_PREP
# um_NUM
# mês_N
# ._.
# O_ART
# animal_N
# mais_ADV
# caro_ADJ
# negociado_PCP
# por_PREP
# Monte_NPROP
# saiu_V
# por_PREP
# Cr$_CUR
# 12,2_NUM
# milhões_N
# (_(
# 12.845_NUM
# URVs_N
# )_)
# ._.
# Foi_V
# a_ART
# égua_N
# reprodutora_ADJ
# Zara_NPROP
# ,_,
# nascida_PCP
# em_PREP
# 1981_N
# ,_,
# importada_PCP
# de_PREP
# Portugal_NPROP
# e_KC
# adquirida_PCP
# por_PREP|+
# o_ART
# Haras_NPROP
# 4_NPROP
# Irmãos_NPROP
# ,_,
# de_PREP
# Cuiabá_NPROP
# (_(
# MT_NPROP
# )_)
# ._.
# Em_PREP|+
# o_ART
# haras_N
# de_PREP
# Monte_NPROP
# funcionam_V
# a_ART
# Escola_NPROP
# Brasileira_NPROP
# de_NPROP
# Arte_NPROP
# Equestre_NPROP
# e_KC
# o_ART
# Centro_NPROP
# de_NPROP
# Treinamento_NPROP
# Itapuã_NPROP
# ._.
# Lá_ADV
# ,_,
# dois_NUM
# cavaleiros_N
# espanhóis_ADJ
# ,_,
# Rafael_NPROP
# Lopez_NPROP
# Candel_NPROP
# e_KC
# Samuel_NPROP
# Lopez_NPROP
# Candel_NPROP
# ,_,
# ensinam_V
# os_ART
# brasileiros_N
# em_PREP|+
# a_ART
# prática_N
# de_PREP|+
# o_ART
# adestramento_N
# básico_ADJ
# e_KC
# superior_ADJ
# ,_,
# de_PREP
# campo_N
# e_KC
# outros_PROADJ
# esportes_N
# hípicos_ADJ
# ._.
# Para_PREP
# o_ART
# leilão_N
# Top_NPROP
# Interagro_NPROP
# ,_,
# que_PRO-KS-REL
# acontece_V
# esta_PROADJ
# noite_N
# ,_,
# Paulo_NPROP
# Pimenta_NPROP
# ,_,
# de_PREP|+
# a_ART
# Pégaso_NPROP
# ,_,
# empresa_N
# organizadora_ADJ
# ,_,
# destaca_V
# em_PREP|+
# a_ART
# oferta_N
# alguns_PROADJ
# filhos_N
# de_PREP|+
# os_ART
# garanhões_N
# andaluzes_ADJ
# Afiançado_NPROP
# e_KC
# Badel_NPROP
# ,_,
# ambos_PROSUB
# de_PREP
# sangue_N
# português_ADJ
# ._.
# Começou_V
# sábado_N
# passado_PCP
# ,_,
# em_PREP
# Londrina_NPROP
# (_(
# PR_NPROP
# )_)
# ,_,
# a_ART
# 34ª_ADJ
# Exposição_NPROP
# Agropecuária_NPROP
# e_NPROP
# Industrial_NPROP
# ._.
# Até_PREP
# domingo_N
# ,_,
# dia_N
# 17_N|AP
# ,_,
# estarão_V
# expostas_ADJ
# 6_NUM
# mil_NUM
# cabeças_N
# de_PREP
# bovinos_N
# e_KC
# equinos_N
# e_KC
# é_VAUX
# esperado_PCP
# faturamento_N
# de_PREP
# US$_CUR
# 3_NUM
# milhões_N
# em_PREP
# 27_NUM
# leilões_N
# ._.
# A_ART
# mostra_N
# de_PREP
# Londrina_NPROP
# é_VAUX
# considerada_PCP
# a_ART
# maior_ADJ
# de_PREP|+
# o_ART
# Paraná_NPROP
# e_KC
# uma_PROSUB
# de_PREP|+
# as_PROSUB
# mais_ADV
# importantes_ADJ
# de_PREP|+
# o_ART
# Brasil_NPROP
# ._.
# Perde_V
# somente_PDEN
# para_PREP
# a_ART
# Expozebu_NPROP
# de_NPROP
# Uberaba_NPROP
# (_(
# MG_NPROP
# )_)
# e_KC
# a_ART
# Expointer_NPROP
# de_NPROP
# Esteio_NPROP
# (_(
# RS_NPROP
# )_)
# ._.
# Os_ART
# 12_NUM
# alqueires_N
# de_PREP|+
# o_ART
# parque_N
# de_PREP
# exposições_N
# Ney_NPROP
# Braga_NPROP
# ,_,
# local_N
# de_PREP|+
# a_ART
# feira_N
# ,_,
# deverão_VAUX
# receber_V
# 800_NUM
# mil_NUM
# pessoas_N
# até_PREP
# o_ART
# encerramento_N
# ._.
# 12_NUM
# mil_NUM
# são_V
# criadores_ADJ
# ._.
# Em_PREP
# sua_PROADJ
# 34ª_ADJ
# versão_N
# ,_,
# a_ART
# mostra_N
# londrinense_ADJ
# ganhou_V
# caráter_N
# internacional_ADJ
# ._.
# Estão_V
# em_PREP
# Londrina_NPROP
# ,_,
# segundo_PREP
# a_ART
# Sociedade_NPROP
# Rural_NPROP
# ,_,
# promotora_N
# de_PREP|+
# o_ART
# evento_N
# ,_,
# criadores_N
# e_KC
# fabricantes_N
# de_PREP
# máquinas_N
# agrícolas_ADJ
# de_PREP
# países_N
# como_PREP
# EUA_NPROP
# ,_,
# França_NPROP
# ,_,
# Nova_NPROP
# Zelândia_NPROP
# ,_,
# Itália_NPROP
# ,_,
# Argentina_NPROP
# e_KC
# Paraguai_NPROP
# ._.
# O_ART
# forte_N
# de_PREP|+
# a_ART
# exposição_N
# de_PREP
# Londrina_NPROP
# é_V
# o_ART
# gado_N
# Zebu_ADJ
# (_(
# cuja_PRO-KS-REL
# origem_N
# é_V
# a_ART
# Índia_NPROP
# )_)
# ,_,
# principalmente_ADV
# o_ART
# nelore_N
# ._.
# Este_PROADJ
# ano_N
# ,_,
# porém_KC
# ,_,
# o_ART
# nelore_N
# divide_V
# a_ART
# atenção_N
# de_PREP|+
# os_ART
# visitantes_N
# com_PREP
# o_ART
# brahma_N
# ,_,
# raça_N
# também_PDEN
# zebuína_ADJ
# ,_,
# mas_KC
# que_PRO-KS-REL
# entrou_V
# em_PREP|+
# o_ART
# Brasil_NPROP
# por_PREP|+
# a_ART
# primeira_ADJ
# vez_N
# há_V
# um_NUM
# mês_N
# ._.
# A_ART
# Sociedade_NPROP
# Rural_NPROP
# do_NPROP
# Paraná_NPROP
# investiu_V
# US$_CUR
# 1,2_NUM
# milhão_N
# em_PREP|+
# os_ART
# preparativos_N
# de_PREP|+
# a_ART
# 34ª_ADJ
# Exposição_N
# ._.
# Mas_KC
# o_ART
# retorno_N
# é_VAUX
# garantido_PCP
# ._.
# "_"
# Somente_PDEN
# em_PREP|+
# o_ART
# setor_N
# industrial_ADJ
# esperamos_V
# um_ART
# movimento_N
# de_PREP
# US$_CUR
# 8_NUM
# milhões_N
# "_"
# ,_,
# afirma_V
# José_NPROP
# Carlos_NPROP
# Tibúrcio_NPROP
# ,_,
# presidente_N
# de_PREP|+
# a_ART
# mostra_N
# e_KC
# secretário_N
# de_PREP|+
# a_ART
# agricultura_N
# de_PREP
# o_ART
# Paraná_NPROP
# ._.
# "_"
# Somados_PCP
# a_PREP|+
# os_ART
# US$_CUR
# 3_NUM
# milhões_N
# de_PREP|+
# o_ART
# leilão_N
# serão_V
# US$_CUR
# 11_NUM
# milhões_N
# "_"
# ,_,
# completa_V
# Tibúrcio_NPROP
# ._.
# em_PREP
# a_ART
# área_N
# de_PREP
# shows_N
# musicais_ADJ
# ,_,
# até_PDEN
# a_ART
# cantora_N
# baiana_ADJ
# Daniela_NPROP
# Mercury_NPROP
# e_KC
# o_ART
# grupo_N
# de_PREP
# rock_N
# Barão_NPROP
# Vermelho_NPROP
# descobriram_V
# o_ART
# filão_N
# de_PREP|+
# as_ART
# grandes_ADJ
# exposições_N
# agropecuárias_ADJ
# ._.
# Suas_PROADJ
# apresentações_N
# foram_VAUX
# feitas_PCP
# em_PREP|+
# o_ART
# último_ADJ
# final_N
# de_PREP
# semana_N
# em_PREP
# um_ART
# megarecinto_N
# recentemente_ADV
# construído_PCP
# com_PREP
# capacidade_N
# para_PREP
# 20_NUM
# mil_NUM
# pessoas_N
# e_KC
# 80_NUM
# camarotes_N
# ._.
# Os_ART
# reflexos_N
# de_PREP|+
# a_ART
# feira_N
# de_PREP
# Londrina_NPROP
# são_VAUX
# sentidos_PCP
# em_PREP
# toda_PROADJ
# a_ART
# cidade_N
# ._.
# Somente_PDEN
# em_PREP|+
# o_ART
# recinto_N
# ,_,
# ela_PROPESS
# gera_V
# emprego_N
# direto_ADJ
# para_PREP
# 3.500_NUM
# pessoas_N
# -_-
# de_PREP|+
# elas_PROPESS
# são_V
# peões_N
# encarregados_PCP
# de_PREP|+
# o_ART
# trato_N
# de_PREP|+
# os_ART
# animais_N
# ._.
# Em_PREP|+
# a_ART
# parte_N
# hoteleira_ADJ
# ,_,
# há_V
# incremento_N
# de_PREP
# hóspedes_N
# em_PREP
# torno_PREP
# de_PREP
# 50_NUM
# %_N
# ._.
# Em_PREP|+
# os_ART
# vôos_N
# ,_,
# o_ART
# aumento_N
# de_PREP
# passageiros_N
# é_V
# de_PREP
# 15_NUM
# %_N
# e_KC
# o_ART
# movimento_N
# de_PREP
# táxi_N
# em_PREP|+
# a_ART
# área_N
# urbana_ADJ
# cresce_V
# 20_NUM
# %_N
# ._.
# Para_PREP
# os_ART
# 11_NUM
# dias_N
# de_PREP
# duração_N
# de_PREP|+
# a_ART
# mostra_N
# foram_VAUX
# instaladas_PCP
# em_PREP|+
# o_ART
# parque_N
# 80_NUM
# linhas_N
# exclusivas_ADJ
# de_PREP
# telefone_N
# ._.
# 34ª_ADJ
# -_-
# De_PREP
# 7_N
# a_PREP
# 17_N
# de_PREP
# abril_N
# ,_,
# em_PREP|+
# o_ART
# parque_N
# de_PREP
# exposições_N
# Ney_NPROP
# Braga_NPROP
# ,_,
# em_PREP
# Londrina_NPROP
# (_(
# PR_NPROP
# )_)
# ._.
# Ingressos_N
# :_:
# Cr$_CUR
# 1_NUM
# mil_NUM
# ._.
# Estacionamento_N
# Cr$_CUR
# 3_N
# mil/veículo_N
# ._.
# Leilão_N
# de_PREP|+
# a_ART
# cabana_N
# Pinhal_NPROP
# ,_,
# de_PREP
# Avaré_NPROP
# (_(
# SP_NPROP
# )_)
# ,_,
# vende_V
# 42_NUM
# animais_N
# e_KC
# fatura_V
# Cr$_CUR
# 59,7_NUM
# milhões_N
# em_PREP
# São_NPROP
# Paulo_NPROP
# ._.
# O_ART
# 3º_ADJ
# ,_,
# dia_N
# 5_N|AP
# último_ADJ
# em_PREP|+
# a_ART
# Churrascaria_NPROP
# Bull's_NPROP
# Grill_NPROP
# $_$
# (_(
# oeste_ADJ
# de_PREP
# São_NPROP
# Paulo_NPROP
# )_)
# ,_,
# conseguiu_V
# comprador_N
# para_PREP
# os_ART
# 42_NUM
# animais_N
# de_PREP|+
# a_ART
# oferta_N
# e_KC
# obteve_V
# faturamento_N
# de_PREP
# Cr$_CUR
# 59,7_NUM
# milhões_N
# ._.
# média_N
# individual_ADJ
# foi_V
# de_PREP
# Cr$_CUR
# 1,4_NUM
# milhão_N
# ,_,
# o_ART
# equivalente_N
# a_PREP
# 1.499_NUM
# URV_N
# (_(
# )_)
# ._.
# A_ART
# jersei_N
# é_V
# uma_ART
# raça_N
# bovina_ADJ
# usada_PCP
# exclusivamente_ADV
# em_PREP|+
# a_ART
# produção_N
# de_PREP
# leite_N
# ._.
# De_PREP
# origem_N
# suíça_ADJ
# ,_,
# está_V
# em_PREP|+
# o_ART
# Brasil_NPROP
# há_V
# 50_NUM
# anos_N
# ._.
# Os_ART
# principais_ADJ
# criadores_N
# de_PREP|+
# a_ART
# raça_N
# são_V
# paulistas_N
# ,_,
# Otto_NPROP
# Ribeiro_NPROP
# Leal_NPROP
# ,_,
# de_PREP
# Avaré_NPROP
# (_(
# 268_NUM
# km_N
# a_PREP
# oeste_N
# de_PREP
# São_NPROP
# Paulo_NPROP
# )_)
# ,_,
# proprietário_N
# de_PREP|+
# a_ART
# Pinhal_NPROP
# e_KC
# promotor_N
# de_PREP|+
# o_ART
# leilão_N
# ._.
# Em_PREP
# tempos_N
# de_PREP
# URV_NPROP
# ,_,
# Leal_NPROP
# vendeu_V
# todos_PROADJ
# os_ART
# lotes_N
# por_PREP|+
# o_ART
# novo_ADJ
# imdexador_N
# ._.
# As_ART
# condições_N
# de_PREP
# pagamento_N
# foram_V
# as_ART
# seguintes_N
# :_:
# 10_NUM
# vezes_N
# mensais_ADJ
# corrigidas_PCP
# por_PREP|+
# a_ART
# URV_NPROP
# ou_KC
# ainda_ADV
# em_PREP
# quatro_NUM
# vezes_N
# mensais_ADJ
# por_PREP|+
# a_ART
# URV_NPROP
# com_PREP
# desconto_N
# de_PREP
# 4_NUM
# %_N
# sobre_PREP
# o_ART
# valor_N
# final_ADJ
# de_PREP|+
# o_ART
# lance_N
# ._.
# "_"
# A_ART
# maioria_N
# de_PREP|+
# os_ART
# compradores_N
# preferiu_V
# a_ART
# segunda_ADJ
# opção_N
# "_"
# ,_,
# diz_V
# José_NPROP
# Ailton_NPROP
# Pupio_NPROP
# ,_,
# de_PREP|+
# a_ART
# empresa_N
# organizadora_ADJ
# de_PREP|+
# o_ART
# pregão_N
# ._.
# Uma_ART
# fêmea_N
# POI_ADJ
# (_(
# pura_ADJ
# de_PREP
# origem_N
# importada_PCP
# )_)
# foi_V
# o_ART
# animal_N
# mais_ADV
# caro_ADJ
# de_PREP|+
# o_ART
# leilão_N
# ._.
# Registrada_PCP
# com_PREP
# nome_N
# de_PREP
# Hironia_NPROP
# S._NPROP
# Jay_NPROP
# Xenia_NPROP
# 31_NUM
# x_N
# ,_,
# foi_VAUX
# comprada_PCP
# por_PREP|+
# o_ART
# criador_N
# carioca_ADJ
# Benedito_NPROP
# Octaviano_NPROP
# Balbino_NPROP
# por_PREP
# Cr$_CUR
# 3,2_NUM
# milhões_N
# (_(
# 3.372_NUM
# URVs_N
# )_)
# ._.
# Balbino_NPROP
# levou_V
# ainda_ADV
# para_PREP
# o_ART
# Rio_NPROP
# de_NPROP
# Janeiro_NPROP
# a_ART
# vaca_N
# W_NPROP
# S_NPROP
# Justin_NPROP
# Jiffy_NPROP
# ._.
# S._NPROP
# Justin_NPROP
# Jiffy_NPROP
# também_PDEN
# importada_PCP
# ,_,
# por_PREP
# Cr$_CUR
# 2,8_NUM
# milhões_N
# (_(
# 2.950_NUM
# URVs_N
# )_)
# ,_,
# segunda_ADJ
# maior_ADJ
# cotação_N
# de_PREP|+
# a_ART
# noite_N
# ._.
# A_ART
# Associação_NPROP
# Brasileira_NPROP
# de_NPROP
# Criadores_NPROP
# de_NPROP
# Gado_NPROP
# Jérsei_NPROP
# do_NPROP
# Brasil_NPROP
# ,_,
# sediada_PCP
# em_PREP
# São_NPROP
# Paulo_NPROP
# ,_,
# anunciou_V
# ,_,
# em_PREP|+
# a_ART
# semana_N
# passada_PCP
# ,_,
# a_ART
# realização_N
# de_PREP|+
# o_ART
# primeiro_ADJ
# remate_N
# oficial_ADJ
# de_PREP|+
# a_ART
# raça_N
# em_PREP|+
# a_ART
# temporada_N
# de_PREP
# 94_N
# ._.
# Será_V
# em_PREP|+
# o_ART
# próximo_ADJ
# dia_N
# 19_N|AP
# ,_,
# em_PREP|+
# o_ART
# Palace_NPROP
# (_(
# sul_ADJ
# de_PREP
# São_NPROP
# Paulo_NPROP
# )_)
# ,_,
# quando_ADV-KS-REL
# 42_NUM
# vacas_N
# em_PREP
# lactação_N
# (_(
# que_PRO-KS-REL
# estão_VAUX
# produzindo_V
# leite_N
# )_)
# serão_VAUX
# colocadas_PCP
# em_PREP
# negócio_N
# ._.
# As_ART
# fêmeas_N
# foram_VAUX
# selecionadas_PCP
# em_PREP|+
# as_ART
# fazendas_N
# de_PREP
# criadores_N
# de_PREP|+
# o_ART
# quadro_N
# de_PREP|+
# a_ART
# associação_N
# ._.
# Os_ART
# organizadores_N
# vão_VAUX
# sortear_V
# um_ART
# automóvel_N
# Citroen_NPROP
# ,_,
# uma_ART
# ensiladeira_N
# e_KC
# um_ART
# telefone_N
# celular_ADJ
# ,_,
# entre_PREP
# os_ART
# presentes_N
# ._.
# Em_PREP|+
# a_ART
# relação_N
# de_PREP
# vendedores_N
# ,_,
# nomes_N
# conhecidos_PCP
# de_PREP|+
# os_ART
# jersistas_N
# ,_,
# como_PREP
# Antonio_NPROP
# Carlos_NPROP
# Pinheiro_NPROP
# Machado_NPROP
# ,_,
# Edgardo_NPROP
# Hector_NPROP
# Perez_NPROP
# ,_,
# Otto_NPROP
# Leal_NPROP
# ,_,
# Paulo_NPROP
# Roberto_NPROP
# Nolli_NPROP
# e_KC
# Sueli_NPROP
# Alves_NPROP
# Nogueira_NPROP
# ._.
# Ainda_ADV
# em_PREP|+
# a_ART
# semana_N
# passada_PCP
# ,_,
# o_ART
# criador_N
# de_PREP
# Itatiba_NPROP
# (_(
# 90_NUM
# km_N
# a_PREP|+
# o_ART
# norte_N
# de_PREP
# São_NPROP
# Paulo_NPROP
# )_)
# ,_,
# Pedro_NPROP
# de_NPROP
# Barros_NPROP
# Mott_NPROP
# ,_,
# tomou_V
# posse_N
# em_PREP|+
# a_ART
# presidência_N
# de_PREP|+
# a_ART
# Associação_NPROP
# Paulista_NPROP
# de_NPROP
# Gado_NPROP
# Jersei_NPROP
# ._.
# Não_ADV
# se_PROPESS
# trata_V
# de_PREP
# qualquer_PROADJ
# dissidência_N
# de_PREP|+
# a_ART
# Associação_NPROP
# Brasileira_NPROP
# ,_,
# esclarece_V
# Mott_NPROP
# ._.
# A_ART
# intenção_N
# ,_,
# explica_V
# ,_,
# discutir_V
# as_ART
# questões_N
# de_PREP|+
# os_ART
# criadores_N
# paulistanos_ADJ
# separadamente_ADV
# ,_,
# com_PREP
# sede_N
# e_KC
# infra-estrutura_N
# montadas_PCP
# em_PREP|+
# a_ART
# capital_N
# ._.

# %% [markdown]
# Vamos fazer o seguinte:
# * Selecionar apenas letras (remover pontuação, números e outros caracteres)
# * Converter o texto para letra minúscula

# %%
folha_sp_letras_min =  re.findall(r'\b[A-zÀ-úü]+\b', folha_sp.lower())

# %%
print(folha_sp_letras_min)
# Out:
# ['jersei_n', 'atinge_v', 'média_n', 'de_prep', 'cr', '_cur', 'milhão_n', 'em_prep', 'a_art', 'venda_n', 'de_prep', 'a_art', 'pinhal_nprop', 'em_prep', 'são_nprop', 'paulo_nprop', '_', 'programe_v', 'sua_proadj', 'viagem_n', 'a_prep', 'a_art', 'exposição_nprop', 'nacional_nprop', 'do_nprop', 'zebu_nprop', '_', 'que_pro', 'ks', 'rel', 'começa_v', 'dia_n', 'ap', '_', 'safra_n', 'recorde_adj', 'e_kc', 'disponibilidade_n', 'de_prep', 'crédito_n', 'ativam_v', 'vendas_n', 'de_prep', 'máquinas_n', 'agrícolas_adj', '_', 'a_art', 'degradação_n', 'de_prep', 'as_art', 'terras_n', 'por_prep', 'o_art', 'mau_adj', 'uso_n', 'de_prep', 'os_art', 'solos_n', 'avança_v', 'em_prep', 'o_art', '_', 'a_art', 'desertificação_n', 'tornou_v', 'crítica_adj', 'a_art', 'produtividade_n', 'de_prep', 'mil_num', 'em_prep', 'a_art', 'região_n', '_', 'em_prep', 'o_art', 'dia_n', 'ap', '_', 'dia_nprop', 'da_nprop', 'conservação_nprop', 'do_nprop', 'solo_nprop', '_', 'o_art', 'único_adj', 'fato_n', 'a_prep', 'festejar_v', 'pode_vaux', 'ser_v', 'a_art', 'convenção_nprop', 'internacional_nprop', 'sobre_nprop', 'desertificação_nprop', '_', 'a_art', 'produção_n', 'brasileira_adj', 'de_prep', 'pintos_n', 'de_prep', 'corte_n', 'totalizou_v', '_', 'em_prep', 'fevereiro_n', 'último_adj', '_', 'milhões_n', '_', 'volume_n', '_n', 'superior_adj', 'a_prep', 'o_art', 'registrado_n', 'em_prep', 'fevereiro_n', 'de_prep', '_', 'segundo_prep', 'dados_n', 'de_prep', 'a_art', 'associação_nprop', 'brasileira_nprop', 'dos_nprop', 'produtores_nprop', 'de_nprop', 'pinto_nprop', 'de_nprop', 'corte_nprop', '_', 'apinco_nprop', '_', '_', 'a_art', 'apinco_nprop', 'destaca_v', 'em_prep', 'seu_proadj', 'boletim_n', 'mensal_adj', 'que_ks', 'o_art', 'setor_n', 'avícola_adj', 'está_v', 'otimista_adj', 'com_prep', 'o_art', 'atual_adj', 'programa_n', 'de_prep', 'estabilização_n', 'econômica_adj', '_', '_', 'a_art', 'melhoria_n', 'de_prep', 'o_art', 'padrão_n', 'aquisitivo_adj', 'resulta_v', 'em_prep', 'maior_adj', 'demanda_n', 'de_prep', 'carne_n', 'de_prep', 'frango_n', '_', '_', 'o_art', 'secretário_n', 'de_prep', 'a_art', 'agricultura_n', 'paulista_adj', '_', 'roberto_nprop', 'rodrigues_nprop', '_', 'aprovou_v', 'o_art', 'pacote_n', 'de_prep', 'o_art', 'trigo_n', '_', 'anunciado_pcp', 'em_prep', 'o_art', 'final_n', 'de_prep', 'março_n', 'por_prep', 'o_art', 'governo_n', 'federal_adj', '_', 'a_art', 'nova_adj', 'alíquota_n', 'para_prep', 'importação_n', 'de_prep', 'o_art', 'produto_n', '_', '_n', '_', 'garante_v', 'a_art', 'competitividade_n', 'de_prep', 'a_art', 'triticultura_n', 'nacional_adj', '_', 'disse_v', 'o_art', 'secretário_n', '_', 'agricultores_n', 'de_prep', 'o_art', 'vale_nprop', 'do_nprop', 'paranapanema_nprop', '_', 'em_prep', 'são_nprop', 'paulo_nprop', '_', 'iniciaram_v', 'ontem_adv', 'o_art', 'plantio_n', 'de_prep', 'trigo_n', 'duro_adj', '_', 'a_art', 'variedade_n', '_', 'para_prep', 'a_art', 'fabricação_n', 'de_prep', 'massas_n', '_', 'foi_vaux', 'selecionada_pcp', 'por_prep', 'o_art', 'instituto_nprop', 'agronômico_nprop', 'de_nprop', 'campinas_nprop', '_', 'o_art', 'governador_n', 'mário_nprop', 'pereira_nprop', '_', 'de_prep', 'o_art', 'paraná_nprop', '_', 'e_kc', 'o_art', 'secretário_n', 'de_prep', 'a_art', 'agricultura_n', 'josé_nprop', 'carlos_nprop', 'tibúrcio_nprop', 'aproveitaram_v', 'o_art', 'palanque_n', 'de_prep', 'a_art', 'exposição_nprop', 'agropecuária_nprop', 'de_nprop', 'londrina_nprop', 'para_prep', 'cobrar_v', 'de_prep', 'o_art', 'ministro_n', 'de_prep', 'a_art', 'agricultura_n', '_', 'synval_nprop', 'guazzelli_nprop', '_', 'um_art', 'novo_adj', 'modelo_n', 'de_prep', 'política_n', 'agrícola_adj', '_', 'capaz_adj', 'de_prep', 'estimular_v', 'investimentos_n', 'e_kc', 'o_art', 'crescimento_n', 'de_prep', 'a_art', 'produção_n', '_', 'antonio_nprop', 'ambrósio_nprop', 'amaro_nprop', 'é_v', 'o_art', 'novo_adj', 'diretor_n', 'de_prep', 'o_art', 'instituto_nprop', 'de_nprop', 'economia_nprop', 'agrícola_nprop', 'da_nprop', 'secretaria_nprop', 'de_nprop', 'agricu ...

# %% [markdown]
# Agora vamos remover as stopwords, ou seja, as palavras que não possuem valor semântico para a busca (exemplo: artigos e preposições. O NLTK fornece bibliotecas de stopwords para vários idiomas.

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')

# %%
print(stopwords)
# Out:
# ['a', 'à', 'ao', 'aos', 'aquela', 'aquelas', 'aquele', 'aqueles', 'aquilo', 'as', 'às', 'até', 'com', 'como', 'da', 'das', 'de', 'dela', 'delas', 'dele', 'deles', 'depois', 'do', 'dos', 'e', 'é', 'ela', 'elas', 'ele', 'eles', 'em', 'entre', 'era', 'eram', 'éramos', 'essa', 'essas', 'esse', 'esses', 'esta', 'está', 'estamos', 'estão', 'estar', 'estas', 'estava', 'estavam', 'estávamos', 'este', 'esteja', 'estejam', 'estejamos', 'estes', 'esteve', 'estive', 'estivemos', 'estiver', 'estivera', 'estiveram', 'estivéramos', 'estiverem', 'estivermos', 'estivesse', 'estivessem', 'estivéssemos', 'estou', 'eu', 'foi', 'fomos', 'for', 'fora', 'foram', 'fôramos', 'forem', 'formos', 'fosse', 'fossem', 'fôssemos', 'fui', 'há', 'haja', 'hajam', 'hajamos', 'hão', 'havemos', 'haver', 'hei', 'houve', 'houvemos', 'houver', 'houvera', 'houverá', 'houveram', 'houvéramos', 'houverão', 'houverei', 'houverem', 'houveremos', 'houveria', 'houveriam', 'houveríamos', 'houvermos', 'houvesse', 'houvessem', 'houvéssemos', 'isso', 'isto', 'já', 'lhe', 'lhes', 'mais', 'mas', 'me', 'mesmo', 'meu', 'meus', 'minha', 'minhas', 'muito', 'na', 'não', 'nas', 'nem', 'no', 'nos', 'nós', 'nossa', 'nossas', 'nosso', 'nossos', 'num', 'numa', 'o', 'os', 'ou', 'para', 'pela', 'pelas', 'pelo', 'pelos', 'por', 'qual', 'quando', 'que', 'quem', 'são', 'se', 'seja', 'sejam', 'sejamos', 'sem', 'ser', 'será', 'serão', 'serei', 'seremos', 'seria', 'seriam', 'seríamos', 'seu', 'seus', 'só', 'somos', 'sou', 'sua', 'suas', 'também', 'te', 'tem', 'tém', 'temos', 'tenha', 'tenham', 'tenhamos', 'tenho', 'terá', 'terão', 'terei', 'teremos', 'teria', 'teriam', 'teríamos', 'teu', 'teus', 'teve', 'tinha', 'tinham', 'tínhamos', 'tive', 'tivemos', 'tiver', 'tivera', 'tiveram', 'tivéramos', 'tiverem', 'tivermos', 'tivesse', 'tivessem', 'tivéssemos', 'tu', 'tua', 'tuas', 'um', 'uma', 'você', 'vocês', 'vos']

# %%
list_stopwords_portugues = set(stopwords)

# %%
folha_sp_letras_min_semstop = [w for w in folha_sp_letras_min if w not in list_stopwords_portugues]

# %%
print(folha_sp_letras_min_semstop)
# Out:
# ['jersei_n', 'atinge_v', 'média_n', 'de_prep', 'cr', '_cur', 'milhão_n', 'em_prep', 'a_art', 'venda_n', 'de_prep', 'a_art', 'pinhal_nprop', 'em_prep', 'são_nprop', 'paulo_nprop', '_', 'programe_v', 'sua_proadj', 'viagem_n', 'a_prep', 'a_art', 'exposição_nprop', 'nacional_nprop', 'do_nprop', 'zebu_nprop', '_', 'que_pro', 'ks', 'rel', 'começa_v', 'dia_n', 'ap', '_', 'safra_n', 'recorde_adj', 'e_kc', 'disponibilidade_n', 'de_prep', 'crédito_n', 'ativam_v', 'vendas_n', 'de_prep', 'máquinas_n', 'agrícolas_adj', '_', 'a_art', 'degradação_n', 'de_prep', 'as_art', 'terras_n', 'por_prep', 'o_art', 'mau_adj', 'uso_n', 'de_prep', 'os_art', 'solos_n', 'avança_v', 'em_prep', 'o_art', '_', 'a_art', 'desertificação_n', 'tornou_v', 'crítica_adj', 'a_art', 'produtividade_n', 'de_prep', 'mil_num', 'em_prep', 'a_art', 'região_n', '_', 'em_prep', 'o_art', 'dia_n', 'ap', '_', 'dia_nprop', 'da_nprop', 'conservação_nprop', 'do_nprop', 'solo_nprop', '_', 'o_art', 'único_adj', 'fato_n', 'a_prep', 'festejar_v', 'pode_vaux', 'ser_v', 'a_art', 'convenção_nprop', 'internacional_nprop', 'sobre_nprop', 'desertificação_nprop', '_', 'a_art', 'produção_n', 'brasileira_adj', 'de_prep', 'pintos_n', 'de_prep', 'corte_n', 'totalizou_v', '_', 'em_prep', 'fevereiro_n', 'último_adj', '_', 'milhões_n', '_', 'volume_n', '_n', 'superior_adj', 'a_prep', 'o_art', 'registrado_n', 'em_prep', 'fevereiro_n', 'de_prep', '_', 'segundo_prep', 'dados_n', 'de_prep', 'a_art', 'associação_nprop', 'brasileira_nprop', 'dos_nprop', 'produtores_nprop', 'de_nprop', 'pinto_nprop', 'de_nprop', 'corte_nprop', '_', 'apinco_nprop', '_', '_', 'a_art', 'apinco_nprop', 'destaca_v', 'em_prep', 'seu_proadj', 'boletim_n', 'mensal_adj', 'que_ks', 'o_art', 'setor_n', 'avícola_adj', 'está_v', 'otimista_adj', 'com_prep', 'o_art', 'atual_adj', 'programa_n', 'de_prep', 'estabilização_n', 'econômica_adj', '_', '_', 'a_art', 'melhoria_n', 'de_prep', 'o_art', 'padrão_n', 'aquisitivo_adj', 'resulta_v', 'em_prep', 'maior_adj', 'demanda_n', 'de_prep', 'carne_n', 'de_prep', 'frango_n', '_', '_', 'o_art', 'secretário_n', 'de_prep', 'a_art', 'agricultura_n', 'paulista_adj', '_', 'roberto_nprop', 'rodrigues_nprop', '_', 'aprovou_v', 'o_art', 'pacote_n', 'de_prep', 'o_art', 'trigo_n', '_', 'anunciado_pcp', 'em_prep', 'o_art', 'final_n', 'de_prep', 'março_n', 'por_prep', 'o_art', 'governo_n', 'federal_adj', '_', 'a_art', 'nova_adj', 'alíquota_n', 'para_prep', 'importação_n', 'de_prep', 'o_art', 'produto_n', '_', '_n', '_', 'garante_v', 'a_art', 'competitividade_n', 'de_prep', 'a_art', 'triticultura_n', 'nacional_adj', '_', 'disse_v', 'o_art', 'secretário_n', '_', 'agricultores_n', 'de_prep', 'o_art', 'vale_nprop', 'do_nprop', 'paranapanema_nprop', '_', 'em_prep', 'são_nprop', 'paulo_nprop', '_', 'iniciaram_v', 'ontem_adv', 'o_art', 'plantio_n', 'de_prep', 'trigo_n', 'duro_adj', '_', 'a_art', 'variedade_n', '_', 'para_prep', 'a_art', 'fabricação_n', 'de_prep', 'massas_n', '_', 'foi_vaux', 'selecionada_pcp', 'por_prep', 'o_art', 'instituto_nprop', 'agronômico_nprop', 'de_nprop', 'campinas_nprop', '_', 'o_art', 'governador_n', 'mário_nprop', 'pereira_nprop', '_', 'de_prep', 'o_art', 'paraná_nprop', '_', 'e_kc', 'o_art', 'secretário_n', 'de_prep', 'a_art', 'agricultura_n', 'josé_nprop', 'carlos_nprop', 'tibúrcio_nprop', 'aproveitaram_v', 'o_art', 'palanque_n', 'de_prep', 'a_art', 'exposição_nprop', 'agropecuária_nprop', 'de_nprop', 'londrina_nprop', 'para_prep', 'cobrar_v', 'de_prep', 'o_art', 'ministro_n', 'de_prep', 'a_art', 'agricultura_n', '_', 'synval_nprop', 'guazzelli_nprop', '_', 'um_art', 'novo_adj', 'modelo_n', 'de_prep', 'política_n', 'agrícola_adj', '_', 'capaz_adj', 'de_prep', 'estimular_v', 'investimentos_n', 'e_kc', 'o_art', 'crescimento_n', 'de_prep', 'a_art', 'produção_n', '_', 'antonio_nprop', 'ambrósio_nprop', 'amaro_nprop', 'é_v', 'o_art', 'novo_adj', 'diretor_n', 'de_prep', 'o_art', 'instituto_nprop', 'de_nprop', 'economia_nprop', 'agrícola_nprop', 'da_nprop', 'secretaria_nprop', 'de_nprop', 'agricu ...

# %% [markdown]
# Também podemos trabalhar com radicais (stemming). Existem duas formas aqui:
#
# *   Stemming - "corta" as palavras usando a raiz como base
# *   Lemmatization - reduz as palavras a forma verdadeira da raiz
#
# Exemplo: andando
#
# *   Stemming - anda
# *   Lemmatization - andar
#
# Lemmatization é uma função mais complexa, portanto, se o texto for muito grande pode demorar um pouco para executá-la.
#
# O nltk possui duas funções para stemming: Porter (PorterStemmer) e Lancaster (LancasterStemmer). Ele também possui um lemmatizador (WordNetLemmatizer).

# %%
porter = nltk.PorterStemmer()

# %%
folha_sp_letras_min_semstop_stem = [porter.stem(t) for t in folha_sp_letras_min_semstop]

# %%
print(folha_sp_letras_min_semstop_stem)
# Out:
# ['jersei_n', 'atinge_v', 'média_n', 'de_prep', 'cr', '_cur', 'milhão_n', 'em_prep', 'a_art', 'venda_n', 'de_prep', 'a_art', 'pinhal_nprop', 'em_prep', 'são_nprop', 'paulo_nprop', '_', 'programe_v', 'sua_proadj', 'viagem_n', 'a_prep', 'a_art', 'exposição_nprop', 'nacional_nprop', 'do_nprop', 'zebu_nprop', '_', 'que_pro', 'ks', 'rel', 'começa_v', 'dia_n', 'ap', '_', 'safra_n', 'recorde_adj', 'e_kc', 'disponibilidade_n', 'de_prep', 'crédito_n', 'ativam_v', 'vendas_n', 'de_prep', 'máquinas_n', 'agrícolas_adj', '_', 'a_art', 'degradação_n', 'de_prep', 'as_art', 'terras_n', 'por_prep', 'o_art', 'mau_adj', 'uso_n', 'de_prep', 'os_art', 'solos_n', 'avança_v', 'em_prep', 'o_art', '_', 'a_art', 'desertificação_n', 'tornou_v', 'crítica_adj', 'a_art', 'produtividade_n', 'de_prep', 'mil_num', 'em_prep', 'a_art', 'região_n', '_', 'em_prep', 'o_art', 'dia_n', 'ap', '_', 'dia_nprop', 'da_nprop', 'conservação_nprop', 'do_nprop', 'solo_nprop', '_', 'o_art', 'único_adj', 'fato_n', 'a_prep', 'festejar_v', 'pode_vaux', 'ser_v', 'a_art', 'convenção_nprop', 'internacional_nprop', 'sobre_nprop', 'desertificação_nprop', '_', 'a_art', 'produção_n', 'brasileira_adj', 'de_prep', 'pintos_n', 'de_prep', 'corte_n', 'totalizou_v', '_', 'em_prep', 'fevereiro_n', 'último_adj', '_', 'milhões_n', '_', 'volume_n', '_n', 'superior_adj', 'a_prep', 'o_art', 'registrado_n', 'em_prep', 'fevereiro_n', 'de_prep', '_', 'segundo_prep', 'dados_n', 'de_prep', 'a_art', 'associação_nprop', 'brasileira_nprop', 'dos_nprop', 'produtores_nprop', 'de_nprop', 'pinto_nprop', 'de_nprop', 'corte_nprop', '_', 'apinco_nprop', '_', '_', 'a_art', 'apinco_nprop', 'destaca_v', 'em_prep', 'seu_proadj', 'boletim_n', 'mensal_adj', 'que_k', 'o_art', 'setor_n', 'avícola_adj', 'está_v', 'otimista_adj', 'com_prep', 'o_art', 'atual_adj', 'programa_n', 'de_prep', 'estabilização_n', 'econômica_adj', '_', '_', 'a_art', 'melhoria_n', 'de_prep', 'o_art', 'padrão_n', 'aquisitivo_adj', 'resulta_v', 'em_prep', 'maior_adj', 'demanda_n', 'de_prep', 'carne_n', 'de_prep', 'frango_n', '_', '_', 'o_art', 'secretário_n', 'de_prep', 'a_art', 'agricultura_n', 'paulista_adj', '_', 'roberto_nprop', 'rodrigues_nprop', '_', 'aprovou_v', 'o_art', 'pacote_n', 'de_prep', 'o_art', 'trigo_n', '_', 'anunciado_pcp', 'em_prep', 'o_art', 'final_n', 'de_prep', 'março_n', 'por_prep', 'o_art', 'governo_n', 'federal_adj', '_', 'a_art', 'nova_adj', 'alíquota_n', 'para_prep', 'importação_n', 'de_prep', 'o_art', 'produto_n', '_', '_n', '_', 'garante_v', 'a_art', 'competitividade_n', 'de_prep', 'a_art', 'triticultura_n', 'nacional_adj', '_', 'disse_v', 'o_art', 'secretário_n', '_', 'agricultores_n', 'de_prep', 'o_art', 'vale_nprop', 'do_nprop', 'paranapanema_nprop', '_', 'em_prep', 'são_nprop', 'paulo_nprop', '_', 'iniciaram_v', 'ontem_adv', 'o_art', 'plantio_n', 'de_prep', 'trigo_n', 'duro_adj', '_', 'a_art', 'variedade_n', '_', 'para_prep', 'a_art', 'fabricação_n', 'de_prep', 'massas_n', '_', 'foi_vaux', 'selecionada_pcp', 'por_prep', 'o_art', 'instituto_nprop', 'agronômico_nprop', 'de_nprop', 'campinas_nprop', '_', 'o_art', 'governador_n', 'mário_nprop', 'pereira_nprop', '_', 'de_prep', 'o_art', 'paraná_nprop', '_', 'e_kc', 'o_art', 'secretário_n', 'de_prep', 'a_art', 'agricultura_n', 'josé_nprop', 'carlos_nprop', 'tibúrcio_nprop', 'aproveitaram_v', 'o_art', 'palanque_n', 'de_prep', 'a_art', 'exposição_nprop', 'agropecuária_nprop', 'de_nprop', 'londrina_nprop', 'para_prep', 'cobrar_v', 'de_prep', 'o_art', 'ministro_n', 'de_prep', 'a_art', 'agricultura_n', '_', 'synval_nprop', 'guazzelli_nprop', '_', 'um_art', 'novo_adj', 'modelo_n', 'de_prep', 'política_n', 'agrícola_adj', '_', 'capaz_adj', 'de_prep', 'estimular_v', 'investimentos_n', 'e_kc', 'o_art', 'crescimento_n', 'de_prep', 'a_art', 'produção_n', '_', 'antonio_nprop', 'ambrósio_nprop', 'amaro_nprop', 'é_v', 'o_art', 'novo_adj', 'diretor_n', 'de_prep', 'o_art', 'instituto_nprop', 'de_nprop', 'economia_nprop', 'agrícola_nprop', 'da_nprop', 'secretaria_nprop', 'de_nprop', 'agricul ...

# %% [markdown]
# Vamos ver a frequência de ocorrência dos termos e tentar enxergar diferenças entre o texto processado com e sem stemming.

# %%
freq_sem_stem = FreqDist(folha_sp_letras_min_semstop)
freq_com_stem = FreqDist(folha_sp_letras_min_semstop_stem)

# %%
print("20 palavras mais frequentes sem stem:")
print(freq_sem_stem.most_common(20))
# Out:
# 20 palavras mais frequentes sem stem:
# [('_', 924), ('de_prep', 562), ('a_art', 358), ('o_art', 354), ('em_prep', 215), ('e_kc', 142), ('os_art', 91), ('ks', 76), ('as_art', 76), ('é_v', 67), ('a_prep', 64), ('por_prep', 62), ('para_prep', 60), ('rel', 59), ('que_pro', 56), ('com_prep', 43), ('de_nprop', 37), ('_n', 32), ('um_art', 31), ('se_propess', 31)]

# %%
print("20 palavras mais frequentes com stem:")
print(freq_com_stem.most_common(20))
# Out:
# 20 palavras mais frequentes com stem:
# [('_', 924), ('de_prep', 562), ('a_art', 358), ('o_art', 354), ('em_prep', 215), ('e_kc', 142), ('os_art', 91), ('ks', 76), ('as_art', 76), ('é_v', 67), ('a_prep', 64), ('por_prep', 62), ('para_prep', 60), ('rel', 59), ('que_pro', 56), ('com_prep', 43), ('de_nprop', 37), ('_n', 32), ('um_art', 31), ('se_propess', 31)]

# %%
plt.figure(figsize = (13, 8))
freq_sem_stem.plot(25, title = "Frequência de Palavras - Sem Stemming")
# Out:
# <Axes: title={'center': 'Frequência de Palavras - Sem Stemming'}, xlabel='Samples', ylabel='Counts'>

# %%
plt.figure(figsize = (13, 8))
freq_com_stem.plot(25, title = "Frequência de Palavras - Com Stemming")
# Out:
# <Axes: title={'center': 'Frequência de Palavras - Com Stemming'}, xlabel='Samples', ylabel='Counts'>
